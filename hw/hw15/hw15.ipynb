# %% [markdown]
# <a name="top"></a>
# # **HW15 Meta Learning: Few-shot Classification**
#
# This is the sample code for homework 15.
#
# Please mail to mlta-2022-spring@googlegroups.com if you have any questions.

# %% [markdown]
# ## **Step 1: Download Data**
#
# Run the cell to download data, which has been pre-processed by TAs.
# The dataset has been augmented, so extra data augmentation is not required.

# %%
workspace_dir = '.'

# Download dataset
# !wget https://github.com/xraychen/shiny-disco/releases/download/Latest/omniglot.tar.gz \
#     -O "{workspace_dir}/Omniglot.tar.gz"
# !wget https://github.com/xraychen/shiny-disco/releases/download/Latest/omniglot-test.tar.gz \
#     -O "{workspace_dir}/Omniglot-test.tar.gz"

# # Use `tar' command to decompress
# !tar -zxf "{workspace_dir}/Omniglot.tar.gz" -C "{workspace_dir}/"
# !tar -zxf "{workspace_dir}/Omniglot-test.tar.gz" -C "{workspace_dir}/"

# %% [markdown]
# ## **Step 2: Build the model**

# %% [markdown]
# ### Library importation

# %%
# Import modules we need
import glob, random
from collections import OrderedDict

import numpy as np
from tqdm.auto import tqdm

import torch, torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms

from PIL import Image
from IPython.display import display

# Check device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"DEVICE = {device}")

# Fix random seeds
random_seed = 900405
random.seed(random_seed)
np.random.seed(random_seed)
torch.manual_seed(random_seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(random_seed)
# Out:
# DEVICE = cuda

# %% [markdown]
# ### Model Construction Preliminaries
#
# Since our task is image classification, we need to build a CNN-based model.
# However, to implement MAML algorithm, we should adjust some code in `nn.Module`.

# %% [markdown]
# Take a look at MAML pseudocode...
#
# <img src="https://i.imgur.com/9aHlvfX.png" width="50%" />
#
# On the 10-th line, what we take gradients on are those $\theta$ representing
# <font color="#0CC">**the original model parameters**</font> (outer loop) instead of those in  the
# <font color="#0C0">**inner loop**</font>, so we need to use `functional_forward` to compute the output
# logits of input image instead of `forward` in `nn.Module`.
#
# The following defines these functions.
#
# <!-- 由於在第10行，我們是要對原本的參數 θ 微分，並非 inner-loop (Line5~8) 的 θ' 微分，因此在 inner-loop，我們需要用 functional forward 的方式算出 input image 的 output logits，而不是直接用 nn.module 裡面的 forward（直接對 θ 微分）。在下面我們分別定義了 functional forward 以及 forward 函數。 -->

# %% [markdown]
# ### Model block definition

# %%
def ConvBlock(in_ch: int, out_ch: int):
    return nn.Sequential(
        nn.Conv2d(in_ch, out_ch, 3, padding=1),
        nn.BatchNorm2d(out_ch),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2, stride=2),
    )


def ConvBlockFunction(x, w, b, w_bn, b_bn):
    x = F.conv2d(x, w, b, padding=1)
    x = F.batch_norm(
        x, running_mean=None, running_var=None, weight=w_bn, bias=b_bn, training=True
    )
    x = F.relu(x)
    x = F.max_pool2d(x, kernel_size=2, stride=2)
    return x

# %% [markdown]
# ### Model definition

# %%
class Classifier(nn.Module):
    def __init__(self, in_ch, k_way):
        super(Classifier, self).__init__()
        self.conv1 = ConvBlock(in_ch, 64)
        self.conv2 = ConvBlock(64, 64)
        self.conv3 = ConvBlock(64, 64)
        self.conv4 = ConvBlock(64, 64)
        self.logits = nn.Linear(64, k_way)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = x.view(x.shape[0], -1)
        x = self.logits(x)
        return x

    def functional_forward(self, x, params):
        """
        Arguments:
        x: input images [batch, 1, 28, 28]
        params: model parameters,
                i.e. weights and biases of convolution
                     and weights and biases of
                                   batch normalization
                type is an OrderedDict

        Arguments:
        x: input images [batch, 1, 28, 28]
        params: The model parameters,
                i.e. weights and biases of convolution
                     and batch normalization layers
                It's an `OrderedDict`
        """
        for block in [1, 2, 3, 4]:
            x = ConvBlockFunction(
                x,
                params[f"conv{block}.0.weight"],
                params[f"conv{block}.0.bias"],
                params.get(f"conv{block}.1.weight"),
                params.get(f"conv{block}.1.bias"),
            )
        x = x.view(x.shape[0], -1)
        x = F.linear(x, params["logits.weight"], params["logits.bias"])
        return x

# %% [markdown]
# ### Create Label
#
# This function is used to create labels.
# In a N-way K-shot few-shot classification problem,
# each task has `n_way` classes, while there are `k_shot` images for each class.
# This is a function that creates such labels.

# %%
def create_label(n_way, k_shot):
    return torch.arange(n_way).repeat_interleave(k_shot).long()


# Try to create labels for 5-way 2-shot setting
create_label(5, 2)
# Out:
# tensor([0, 0, 1, 1, 2, 2, 3, 3, 4, 4])

# %% [markdown]
# ### Accuracy calculation

# %%
def calculate_accuracy(logits, labels):
    """utility function for accuracy calculation"""
    acc = np.asarray(
        [(torch.argmax(logits, -1).cpu().numpy() == labels.cpu().numpy())]
    ).mean()
    return acc

# %% [markdown]
# ### Define Dataset
#
# Define the dataset.
# The dataset returns images of a random character, with (`k_shot + q_query`) images,
# so the size of returned tensor is `[k_shot+q_query, 1, 28, 28]`.

# %%
# Dataset for train and val
class Omniglot(Dataset):
    def __init__(self, data_dir, k_way, q_query, task_num=None):
        self.file_list = [
            f for f in glob.glob(data_dir + "**/character*", recursive=True)
        ]
        # limit task number if task_num is set
        if task_num is not None:
            self.file_list = self.file_list[: min(len(self.file_list), task_num)]
        self.transform = transforms.Compose([transforms.ToTensor()])
        self.n = k_way + q_query

    def __getitem__(self, idx):
        sample = np.arange(20)

        # For random sampling the characters we want.
        np.random.shuffle(sample)
        img_path = self.file_list[idx]
        img_list = [f for f in glob.glob(img_path + "**/*.png", recursive=True)]
        img_list.sort()
        imgs = [self.transform(Image.open(img_file)) for img_file in img_list]
        # `k_way + q_query` examples for each character
        imgs = torch.stack(imgs)[sample[: self.n]]
        return imgs

    def __len__(self):
        return len(self.file_list)

# %% [markdown]
# ## **Step 3: Learning Algorithms**
#
# ### Transfer learning
#
# The solver first chose five task from the training set, then do normal classification training on the chosen five tasks. In inference, the model finetune for `inner_train_step` steps on the support set images, and than do inference on the query set images.
#
# For consistant with the meta-learning solver, the base solver has the exactly same input and output format with the meta-learning solver.

# %%
def BaseSolver(
    model,
    optimizer,
    x,
    n_way,
    k_shot,
    q_query,
    loss_fn,
    inner_train_step=1,
    inner_lr=0.4,
    train=True,
    return_labels=False,
):
    criterion, task_loss, task_acc = loss_fn, [], []
    labels = []

    for meta_batch in x:
        # Get data
        support_set = meta_batch[: n_way * k_shot]
        query_set = meta_batch[n_way * k_shot :]

        if train:
            """ training loop """
            # Use the support set to calculate loss
            labels = create_label(n_way, k_shot).to(device)
            logits = model.forward(support_set)
            loss = criterion(logits, labels)

            task_loss.append(loss)
            task_acc.append(calculate_accuracy(logits, labels))
        else:
            """ validation / testing loop """
            # First update model with support set images for `inner_train_step` steps
            fast_weights = OrderedDict(model.named_parameters())


            for inner_step in range(inner_train_step):
                # Simply training
                train_label = create_label(n_way, k_shot).to(device)
                logits = model.functional_forward(support_set, fast_weights)
                loss = criterion(logits, train_label)

                grads = torch.autograd.grad(loss, fast_weights.values(), create_graph=True)
                # Perform SGD
                fast_weights = OrderedDict(
                    (name, param - inner_lr * grad)
                    for ((name, param), grad) in zip(fast_weights.items(), grads)
                )

            if not return_labels:
                """ validation """
                val_label = create_label(n_way, q_query).to(device)

                logits = model.functional_forward(query_set, fast_weights)
                loss = criterion(logits, val_label)
                task_loss.append(loss)
                task_acc.append(calculate_accuracy(logits, val_label))
            else:
                """ testing """
                logits = model.functional_forward(query_set, fast_weights)
                labels.extend(torch.argmax(logits, -1).cpu().numpy())

    if return_labels:
        return labels

    batch_loss = torch.stack(task_loss).mean()
    task_acc = np.mean(task_acc)

    if train:
        # Update model
        model.train()
        optimizer.zero_grad()
        batch_loss.backward()
        optimizer.step()

    return batch_loss, task_acc

# %% [markdown]
# ### Meta Learning
#
# Here is the main Meta Learning algorithm.
#
# Please finish the TODO blocks for the inner and outer loop update rules.
#
# - For implementing FO-MAML you can refer to [p.25 of the slides](http://speech.ee.ntu.edu.tw/~tlkagk/courses/ML_2019/Lecture/Meta1%20(v6).pdf#page=25&view=FitW).
#
# - For the original MAML, you can refer to [the slides of meta learning (p.13 ~ p.18)](http://speech.ee.ntu.edu.tw/~tlkagk/courses/ML_2019/Lecture/Meta1%20(v6).pdf#page=13&view=FitW).

# %%
def inner_update(fast_weights, loss, inner_lr):
    grads = torch.autograd.grad(
        loss, list(fast_weights.values())[-2:], create_graph=True)
    # Split out the logits
    for ((name, param), grad) in zip(
        list(fast_weights.items())[-2:], grads):
        fast_weights[name] = param - inner_lr * grad
    return fast_weights

# %%
def collect_gradients(
    special_grad: OrderedDict, fast_weights, model, len_data):
    diff = OrderedDict(
        (name, params - fast_weights[name]) 
        for (name, params) in model.named_parameters())
    for name in diff:
        special_grad[name] = special_grad.get(name, 0) + diff[name] / len_data
    return special_grad

# %%
def outer_update(model, meta_batch_loss, grad_tensors):
    meta_batch_loss.backward()

# %%
def MetaSolver(
    model,
    optimizer,
    x,
    n_way,
    k_shot,
    q_query,
    loss_fn,
    inner_train_step=1,
    inner_lr=0.4,
    train=True,
    return_labels=False
):
    criterion, task_loss, task_acc = loss_fn, [], []
    labels = []
    special_grad = OrderedDict() 

    for meta_batch in x:
        # Get data
        support_set = meta_batch[: n_way * k_shot]
        query_set = meta_batch[n_way * k_shot :]

        # Copy the params for inner loop
        fast_weights = OrderedDict(model.named_parameters())

        ### ---------- INNER TRAIN LOOP ---------- ###
        for inner_step in range(inner_train_step):
            # Simply training
            train_label = create_label(n_way, k_shot).to(device)
            logits = model.functional_forward(support_set, fast_weights)
            loss = criterion(logits, train_label)
            # Inner gradients update! vvvvvvvvvvvvvvvvvvvv #
            """ Inner Loop Update """
            # TODO: Finish the inner loop update rule
            fast_weights = inner_update(fast_weights, loss, inner_lr)
            # ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ #

        ### ---------- INNER VALID LOOP ---------- ###
        if not return_labels:
            """ training / validation """
            val_label = create_label(n_way, q_query).to(device)
            # special_grad = collect_gradients(special_grad, fast_weights, model, len(x))

            # Collect gradients for outer loop
            logits = model.functional_forward(query_set, fast_weights)
            loss = criterion(logits, val_label)
            task_loss.append(loss)
            task_acc.append(calculate_accuracy(logits, val_label))
        else:
            """ testing """
            logits = model.functional_forward(query_set, fast_weights)
            labels.extend(torch.argmax(logits, -1).cpu().numpy())

    if return_labels:
        return labels

    # Update outer loop
    model.train()
    optimizer.zero_grad()

    meta_batch_loss = torch.stack(task_loss).mean()
    if train:
        """ Outer Loop Update """
        # TODO: Finish the outer loop update
        outer_update(model, meta_batch_loss, special_grad)
        optimizer.step()

    task_acc = np.mean(task_acc)
    return meta_batch_loss, task_acc

# %% [markdown]
# ## **Step 4: Initialization**
#
# After defining all components we need, the following initialize a model before training.

# %% [markdown]
# ### Hyperparameters

# %%
n_way = 5
k_shot = 1
q_query = 1
train_inner_train_step = 1
val_inner_train_step = 3
inner_lr = 0.4
meta_lr = 0.001
meta_batch_size = 32
max_epoch = 1000
eval_batches = 20
train_data_path = "./Omniglot/images_background/"

# %% [markdown]
# ### Dataloader initialization

# %%
def dataloader_init(datasets, shuffle=True, num_workers=2):
    train_set, val_set = datasets
    train_loader = DataLoader(
        train_set,
        # The "batch_size" here is not \
        #    the meta batch size, but  \
        #    how many different        \
        #    characters in a task,     \
        #    i.e. the "n_way" in       \
        #    few-shot classification.
        batch_size=n_way,
        num_workers=num_workers,
        shuffle=shuffle,
        drop_last=True,
    )
    val_loader = DataLoader(
        val_set, batch_size=n_way, num_workers=num_workers, shuffle=shuffle, drop_last=True
    )

    train_iter = iter(train_loader)
    val_iter = iter(val_loader)
    return (train_loader, val_loader), (train_iter, val_iter)

# %% [markdown]
# ### Model & optimizer initialization

# %%
def model_init():
    meta_model = Classifier(1, n_way).to(device)
    optimizer = torch.optim.Adam(meta_model.parameters(), lr=meta_lr)
    loss_fn = nn.CrossEntropyLoss().to(device)
    return meta_model, optimizer, loss_fn

# %% [markdown]
# ### Utility function to get a meta-batch

# %%
def get_meta_batch(meta_batch_size, k_shot, q_query, data_loader, iterator):
    data = []
    for _ in range(meta_batch_size):
        try:
            # a "task_data" tensor is representing \
            #     the data of a task, with size of \
            #     [n_way, k_shot+q_query, 1, 28, 28]
            task_data = iterator.next()
        except StopIteration:
            iterator = iter(data_loader)
            task_data = iterator.next()
        train_data = task_data[:, :k_shot].reshape(-1, 1, 28, 28)
        val_data = task_data[:, k_shot:].reshape(-1, 1, 28, 28)
        task_data = torch.cat((train_data, val_data), 0)
        data.append(task_data)
    return torch.stack(data).to(device), iterator

# %% [markdown]
# <a name="mainprog" id="mainprog"></a>
# ## **Step 5: Main program for training & testing**

# %% [markdown]
# ### Start training!
# With `solver = 'base'`, the solver is a transfer learning algorithm.
#
# Once you finish the TODO blocks in the `MetaSolver`, change the variable `solver = 'meta'` to start training with meta learning algorithm.

# %%
solver = 'meta' # base, meta
meta_model, optimizer, loss_fn = model_init()

# init solver and dataset according to solver type
if solver == 'base':
    max_epoch = 5 # the base solver only needs 5 epochs
    Solver = BaseSolver
    train_set, val_set = torch.utils.data.random_split(
        Omniglot(train_data_path, k_shot, q_query, task_num=10), [5, 5]
    )
    (train_loader, val_loader), (train_iter, val_iter) = dataloader_init((train_set, val_set), shuffle=False)

elif solver == 'meta':
    Solver = MetaSolver
    dataset = Omniglot(train_data_path, k_shot, q_query)
    train_split = int(0.8 * len(dataset))
    val_split = len(dataset) - train_split
    train_set, val_set = torch.utils.data.random_split(
        dataset, [train_split, val_split]
    )
    (train_loader, val_loader), (train_iter, val_iter) = dataloader_init((train_set, val_set))
else:
    raise NotImplementedError


# main training loop
for epoch in range(max_epoch):
    print("Epoch %d" % (epoch + 1))
    train_meta_loss = []
    train_acc = []
    # The "step" here is a meta-gradinet update step
    for step in range(max(1, len(train_loader) // meta_batch_size)):
        x, train_iter = get_meta_batch(
            meta_batch_size, k_shot, q_query, train_loader, train_iter
        )
        meta_loss, acc = Solver(
            meta_model,
            optimizer,
            x,
            n_way,
            k_shot,
            q_query,
            loss_fn, 
            inner_train_step=train_inner_train_step
        )
        train_meta_loss.append(meta_loss.item())
        train_acc.append(acc)
    print("  Loss    : ", "%.3f" % (np.mean(train_meta_loss)), end="\t")
    print("  Accuracy: ", "%.3f %%" % (np.mean(train_acc) * 100))

    # See the validation accuracy after each epoch.
    # Early stopping is welcomed to implement.
    val_acc = []
    for eval_step in range(max(1, len(val_loader) // (eval_batches))):
        x, val_iter = get_meta_batch(
            eval_batches, k_shot, q_query, val_loader, val_iter
        )
        # We update three inner steps when testing.
        _, acc = Solver(
            meta_model,
            optimizer,
            x,
            n_way,
            k_shot,
            q_query,
            loss_fn,
            inner_train_step=val_inner_train_step,
            train=False,
        )
        val_acc.append(acc)
    print("  Validation accuracy: ", "%.3f %%" % (np.mean(val_acc) * 100))
# Out:
# Epoch 1
#   Loss    :  2.188	  Accuracy:  29.219 %
#   Validation accuracy:  57.000 %
# Epoch 2
#   Loss    :  1.417	  Accuracy:  41.875 %
#   Validation accuracy:  51.000 %
# Epoch 3
#   Loss    :  1.346	  Accuracy:  47.188 %
#   Validation accuracy:  57.000 %
# Epoch 4
#   Loss    :  1.268	  Accuracy:  51.250 %
#   Validation accuracy:  64.000 %
# Epoch 5
#   Loss    :  1.164	  Accuracy:  52.969 %
#   Validation accuracy:  56.000 %
# Epoch 6
#   Loss    :  1.139	  Accuracy:  52.969 %
#   Validation accuracy:  65.000 %
# Epoch 7
#   Loss    :  1.036	  Accuracy:  56.250 %
#   Validation accuracy:  56.000 %
# Epoch 8
#   Loss    :  1.040	  Accuracy:  59.219 %
#   Validation accuracy:  61.000 %
# Epoch 9
#   Loss    :  0.933	  Accuracy:  64.219 %
#   Validation accuracy:  47.000 %
# Epoch 10
#   Loss    :  0.907	  Accuracy:  65.156 %
#   Validation accuracy:  57.000 %
# Epoch 11
#   Loss    :  0.895	  Accuracy:  62.031 %
#   Validation accuracy:  64.000 %
# Epoch 12
#   Loss    :  0.830	  Accuracy:  66.875 %
#   Validation accuracy:  66.000 %
# Epoch 13
#   Loss    :  0.793	  Accuracy:  70.625 %
#   Validation accuracy:  65.000 %
# Epoch 14
#   Loss    :  0.747	  Accuracy:  71.719 %
#   Validation accuracy:  61.000 %
# Epoch 15
#   Loss    :  0.747	  Accuracy:  70.156 %
#   Validation accuracy:  72.000 %
# Epoch 16
#   Loss    :  0.699	  Accuracy:  75.000 %
#   Validation accuracy:  73.000 %
# Epoch 17
#   Loss    :  0.634	  Accuracy:  76.875 %
#   Validation accuracy:  68.000 %
# Epoch 18
#   Loss    :  0.644	  Accuracy:  75.938 %
#   Validation accuracy:  66.000 %
# Epoch 19
#   Loss    :  0.591	  Accuracy:  78.750 %
#   Validation accuracy:  74.000 %
# Epoch 20
#   Loss    :  0.576	  Accuracy:  80.469 %
#   Validation accuracy:  75.000 %
# Epoch 21
#   Loss    :  0.562	  Accuracy:  79.531 %
#   Validation accuracy:  75.000 %
# Epoch 22
#   Loss    :  0.570	  Accuracy:  82.031 %
#   Validation accuracy:  72.000 %
# Epoch 23
#   Loss    :  0.505	  Accuracy:  82.969 %
#   Validation accuracy:  69.000 %
# Epoch 24
#   Loss    :  0.518	  Accuracy:  82.813 %
#   Validation accuracy:  71.000 %
# Epoch 25
#   Loss    :  0.456	  Accuracy:  85.312 %
#   Validation accuracy:  79.000 %
# Epoch 26
#   Loss    :  0.469	  Accuracy:  83.750 %
#   Validation accuracy:  76.000 %
# Epoch 27
#   Loss    :  0.446	  Accuracy:  84.062 %
#   Validation accuracy:  79.000 %
# Epoch 28
#   Loss    :  0.444	  Accuracy:  84.844 %
#   Validation accuracy:  79.000 %
# Epoch 29
#   Loss    :  0.470	  Accuracy:  82.812 %
#   Validation accuracy:  76.000 %
# Epoch 30
#   Loss    :  0.440	  Accuracy:  83.594 %
#   Validation accuracy:  70.000 %
# Epoch 31
#   Loss    :  0.404	  Accuracy:  85.938 %
#   Validation accuracy:  83.000 %
# Epoch 32
#   Loss    :  0.384	  Accuracy:  88.906 %
#   Validation accuracy:  80.000 %
# Epoch 33
#   Loss    :  0.403	  Accuracy:  86.719 %
#   Validation accuracy:  89.000 %
# Epoch 34
#   Loss    :  0.416	  Accuracy:  85.938 %
#   Validation accuracy:  82.000 %
# Epoch 35
#   Loss    :  0.395	  Accuracy:  84.688 %
#   Validation accuracy:  74.000 %
# Epoch 36
#   Loss    :  0.415	  Accuracy:  85.781 %
#   Validation accuracy:  78.000 %
# Epoch 37
#   Loss    :  0.353	  Accuracy:  88.281 %
#   Validation accuracy:  87.000 %
# Epoch 38
#   Loss    :  0.394	  Accuracy:  85.156 %
#   Validation accuracy:  87.000 %
# Epoch 39
#   Loss    :  0.391	  Accuracy:  86.406 %
#   Validation accuracy:  85.000 %
# Epoch 40
#   Loss    :  0.364	  Accuracy:  88.594 %
#   Validation accuracy:  84.000 %
# Epoch 41
#   Loss    :  0.359	  Accuracy:  88.594 %
#   Validation accuracy:  91.000 %
# Epoch 42
#   Loss    :  0.340	  Accuracy:  90.156 %
#   Validation accuracy:  85.000 %
# Epoch 43
#   Loss    :  0.326	  Accuracy:  90.625 %
#   Validation accuracy:  90.000 %
# Epoch 44
#   Loss    :  0.304	  Accuracy:  91.250 %
#   Validation accuracy:  79.000 %
# Epoch 45
#   Loss    :  0.338	  Accuracy:  88.281 %
#   Validation accuracy:  79.000 %
# Epoch 46
#   Loss    :  0.283	  Accuracy:  89.688 %
#   Validation accuracy:  84.000 %
# Epoch 47
#   Loss    :  0.340	  Accuracy:  88.438 %
#   Validation accuracy:  88.000 %
# Epoch 48
#   Loss    :  0.311	  Accuracy:  89.219 %
#   Validation accuracy:  83.000 %
# Epoch 49
#   Loss    :  0.331	  Accuracy:  88.437 %
#   Validation accuracy:  92.000 %
# Epoch 50
#   Loss    :  0.337	  Accuracy:  87.812 %
#   Validation accuracy:  88.000 %
# Epoch 51
#   Loss    :  0.323	  Accuracy:  89.375 %
#   Validation accuracy:  89.000 %
# Epoch 52
#   Loss    :  0.352	  Accuracy:  87.344 %
#   Validation accuracy:  84.000 %
# Epoch 53
#   Loss    :  0.277	  Accuracy:  90.938 %
#   Validation accuracy:  87.000 %
# Epoch 54
#   Loss    :  0.299	  Accuracy:  91.250 %
#   Validation accuracy:  84.000 %
# Epoch 55
#   Loss    :  0.313	  Accuracy:  88.750 %
#   Validation accuracy:  89.000 %
# Epoch 56
#   Loss    :  0.248	  Accuracy:  91.719 %
#   Validation accuracy:  86.000 %
# Epoch 57
#   Loss    :  0.310	  Accuracy:  88.438 %
#   Validation accuracy:  88.000 %
# Epoch 58
#   Loss    :  0.273	  Accuracy:  91.719 %
#   Validation accuracy:  92.000 %
# Epoch 59
#   Loss    :  0.278	  Accuracy:  90.781 %
#   Validation accuracy:  91.000 %
# Epoch 60
#   Loss    :  0.242	  Accuracy:  92.656 %
#   Validation accuracy:  91.000 %
# Epoch 61
#   Loss    :  0.270	  Accuracy:  90.781 %
#   Validation accuracy:  91.000 %
# Epoch 62
#   Loss    :  0.256	  Accuracy:  93.125 %
#   Validation accuracy:  88.000 %
# Epoch 63
#   Loss    :  0.266	  Accuracy:  89.844 %
#   Validation accuracy:  88.000 %
# Epoch 64
#   Loss    :  0.273	  Accuracy:  90.000 %
#   Validation accuracy:  86.000 %
# Epoch 65
#   Loss    :  0.242	  Accuracy:  92.656 %
#   Validation accuracy:  81.000 %
# Epoch 66
#   Loss    :  0.274	  Accuracy:  90.156 %
#   Validation accuracy:  92.000 %
# Epoch 67
#   Loss    :  0.248	  Accuracy:  91.875 %
#   Validation accuracy:  91.000 %
# Epoch 68
#   Loss    :  0.259	  Accuracy:  90.781 %
#   Validation accuracy:  87.000 %
# Epoch 69
#   Loss    :  0.246	  Accuracy:  92.188 %
#   Validation accuracy:  89.000 %
# Epoch 70
#   Loss    :  0.246	  Accuracy:  91.406 %
#   Validation accuracy:  91.000 %
# Epoch 71
#   Loss    :  0.268	  Accuracy:  90.781 %
#   Validation accuracy:  95.000 %
# Epoch 72
#   Loss    :  0.228	  Accuracy:  92.656 %
#   Validation accuracy:  92.000 %
# Epoch 73
#   Loss    :  0.226	  Accuracy:  93.125 %
#   Validation accuracy:  89.000 %
# Epoch 74
#   Loss    :  0.253	  Accuracy:  90.781 %
#   Validation accuracy:  90.000 %
# Epoch 75
#   Loss    :  0.265	  Accuracy:  91.875 %
#   Validation accuracy:  90.000 %
# Epoch 76
#   Loss    :  0.272	  Accuracy:  89.844 %
#   Validation accuracy:  92.000 %
# Epoch 77
#   Loss    :  0.219	  Accuracy:  94.062 %
#   Validation accuracy:  88.000 %
# Epoch 78
#   Loss    :  0.249	  Accuracy:  91.719 %
#   Validation accuracy:  84.000 %
# Epoch 79
#   Loss    :  0.256	  Accuracy:  91.562 %
#   Validation accuracy:  92.000 %
# Epoch 80
#   Loss    :  0.224	  Accuracy:  92.656 %
#   Validation accuracy:  91.000 %
# Epoch 81
#   Loss    :  0.211	  Accuracy:  93.281 %
#   Validation accuracy:  94.000 %
# Epoch 82
#   Loss    :  0.237	  Accuracy:  92.812 %
#   Validation accuracy:  87.000 %
# Epoch 83
#   Loss    :  0.205	  Accuracy:  94.375 %
#   Validation accuracy:  90.000 %
# Epoch 84
#   Loss    :  0.227	  Accuracy:  92.656 %
#   Validation accuracy:  93.000 %
# Epoch 85
#   Loss    :  0.193	  Accuracy:  94.844 %
#   Validation accuracy:  84.000 %
# Epoch 86
#   Loss    :  0.198	  Accuracy:  94.687 %
#   Validation accuracy:  92.000 %
# Epoch 87
#   Loss    :  0.170	  Accuracy:  95.469 %
#   Validation accuracy:  90.000 %
# Epoch 88
#   Loss    :  0.219	  Accuracy:  92.500 %
#   Validation accuracy:  97.000 %
# Epoch 89
#   Loss    :  0.214	  Accuracy:  93.438 %
#   Validation accuracy:  91.000 %
# Epoch 90
#   Loss    :  0.197	  Accuracy:  93.750 %
#   Validation accuracy:  92.000 %
# Epoch 91
#   Loss    :  0.186	  Accuracy:  93.438 %
#   Validation accuracy:  97.000 %
# Epoch 92
#   Loss    :  0.189	  Accuracy:  94.219 %
#   Validation accuracy:  97.000 %
# Epoch 93
#   Loss    :  0.194	  Accuracy:  93.750 %
#   Validation accuracy:  95.000 %
# Epoch 94
#   Loss    :  0.208	  Accuracy:  92.500 %
#   Validation accuracy:  94.000 %
# Epoch 95
#   Loss    :  0.175	  Accuracy:  93.906 %
#   Validation accuracy:  85.000 %
# Epoch 96
#   Loss    :  0.174	  Accuracy:  94.219 %
#   Validation accuracy:  90.000 %
# Epoch 97
#   Loss    :  0.187	  Accuracy:  93.594 %
#   Validation accuracy:  92.000 %
# Epoch 98
#   Loss    :  0.196	  Accuracy:  93.750 %
#   Validation accuracy:  91.000 %
# Epoch 99
#   Loss    :  0.207	  Accuracy:  92.656 %
#   Validation accuracy:  90.000 %
# Epoch 100
#   Loss    :  0.162	  Accuracy:  95.000 %
#   Validation accuracy:  92.000 %
# Epoch 101
#   Loss    :  0.189	  Accuracy:  93.281 %
#   Validation accuracy:  93.000 %
# Epoch 102
#   Loss    :  0.231	  Accuracy:  92.500 %
#   Validation accuracy:  91.000 %
# Epoch 103
#   Loss    :  0.175	  Accuracy:  94.062 %
#   Validation accuracy:  96.000 %
# Epoch 104
#   Loss    :  0.190	  Accuracy:  93.125 %
#   Validation accuracy:  91.000 %
# Epoch 105
#   Loss    :  0.172	  Accuracy:  94.375 %
#   Validation accuracy:  88.000 %
# Epoch 106
#   Loss    :  0.175	  Accuracy:  94.062 %
#   Validation accuracy:  94.000 %
# Epoch 107
#   Loss    :  0.207	  Accuracy:  93.906 %
#   Validation accuracy:  97.000 %
# Epoch 108
#   Loss    :  0.175	  Accuracy:  95.000 %
#   Validation accuracy:  93.000 %
# Epoch 109
#   Loss    :  0.162	  Accuracy:  93.594 %
#   Validation accuracy:  92.000 %
# Epoch 110
#   Loss    :  0.165	  Accuracy:  94.531 %
#   Validation accuracy:  92.000 %
# Epoch 111
#   Loss    :  0.167	  Accuracy:  93.594 %
#   Validation accuracy:  93.000 %
# Epoch 112
#   Loss    :  0.183	  Accuracy:  94.844 %
#   Validation accuracy:  97.000 %
# Epoch 113
#   Loss    :  0.171	  Accuracy:  94.219 %
#   Validation accuracy:  96.000 %
# Epoch 114
#   Loss    :  0.163	  Accuracy:  94.062 %
#   Validation accuracy:  92.000 %
# Epoch 115
#   Loss    :  0.172	  Accuracy:  94.844 %
#   Validation accuracy:  92.000 %
# Epoch 116
#   Loss    :  0.170	  Accuracy:  94.687 %
#   Validation accuracy:  96.000 %
# Epoch 117
#   Loss    :  0.149	  Accuracy:  94.531 %
#   Validation accuracy:  95.000 %
# Epoch 118
#   Loss    :  0.140	  Accuracy:  96.562 %
#   Validation accuracy:  91.000 %
# Epoch 119
#   Loss    :  0.177	  Accuracy:  94.062 %
#   Validation accuracy:  91.000 %
# Epoch 120
#   Loss    :  0.147	  Accuracy:  95.938 %
#   Validation accuracy:  94.000 %
# Epoch 121
#   Loss    :  0.145	  Accuracy:  95.469 %
#   Validation accuracy:  88.000 %
# Epoch 122
#   Loss    :  0.121	  Accuracy:  96.406 %
#   Validation accuracy:  91.000 %
# Epoch 123
#   Loss    :  0.166	  Accuracy:  94.375 %
#   Validation accuracy:  98.000 %
# Epoch 124
#   Loss    :  0.147	  Accuracy:  96.094 %
#   Validation accuracy:  92.000 %
# Epoch 125
#   Loss    :  0.173	  Accuracy:  93.750 %
#   Validation accuracy:  90.000 %
# Epoch 126
#   Loss    :  0.157	  Accuracy:  95.469 %
#   Validation accuracy:  98.000 %
# Epoch 127
#   Loss    :  0.143	  Accuracy:  96.250 %
#   Validation accuracy:  98.000 %
# Epoch 128
#   Loss    :  0.129	  Accuracy:  96.406 %
#   Validation accuracy:  93.000 %
# Epoch 129
#   Loss    :  0.151	  Accuracy:  94.844 %
#   Validation accuracy:  92.000 %
# Epoch 130
#   Loss    :  0.123	  Accuracy:  96.562 %
#   Validation accuracy:  96.000 %
# Epoch 131
#   Loss    :  0.122	  Accuracy:  96.406 %
#   Validation accuracy:  90.000 %
# Epoch 132
#   Loss    :  0.140	  Accuracy:  95.312 %
#   Validation accuracy:  89.000 %
# Epoch 133
#   Loss    :  0.123	  Accuracy:  96.094 %
#   Validation accuracy:  96.000 %
# Epoch 134
#   Loss    :  0.113	  Accuracy:  96.094 %
#   Validation accuracy:  97.000 %
# Epoch 135
#   Loss    :  0.150	  Accuracy:  94.844 %
#   Validation accuracy:  96.000 %
# Epoch 136
#   Loss    :  0.127	  Accuracy:  96.406 %
#   Validation accuracy:  94.000 %
# Epoch 137
#   Loss    :  0.123	  Accuracy:  95.938 %
#   Validation accuracy:  93.000 %
# Epoch 138
#   Loss    :  0.138	  Accuracy:  95.312 %
#   Validation accuracy:  97.000 %
# Epoch 139
#   Loss    :  0.163	  Accuracy:  94.844 %
#   Validation accuracy:  95.000 %
# Epoch 140
#   Loss    :  0.140	  Accuracy:  95.938 %
#   Validation accuracy:  97.000 %
# Epoch 141
#   Loss    :  0.145	  Accuracy:  94.531 %
#   Validation accuracy:  96.000 %
# Epoch 142
#   Loss    :  0.130	  Accuracy:  96.719 %
#   Validation accuracy:  90.000 %
# Epoch 143
#   Loss    :  0.145	  Accuracy:  94.844 %
#   Validation accuracy:  92.000 %
# Epoch 144
#   Loss    :  0.143	  Accuracy:  95.156 %
#   Validation accuracy:  95.000 %
# Epoch 145
#   Loss    :  0.133	  Accuracy:  95.156 %
#   Validation accuracy:  95.000 %
# Epoch 146
#   Loss    :  0.113	  Accuracy:  96.562 %
#   Validation accuracy:  89.000 %
# Epoch 147
#   Loss    :  0.128	  Accuracy:  95.781 %
#   Validation accuracy:  94.000 %
# Epoch 148
#   Loss    :  0.137	  Accuracy:  95.938 %
#   Validation accuracy:  94.000 %
# Epoch 149
#   Loss    :  0.131	  Accuracy:  96.562 %
#   Validation accuracy:  93.000 %
# Epoch 150
#   Loss    :  0.140	  Accuracy:  95.469 %
#   Validation accuracy:  96.000 %
# Epoch 151
#   Loss    :  0.146	  Accuracy:  95.156 %
#   Validation accuracy:  88.000 %
# Epoch 152
#   Loss    :  0.167	  Accuracy:  94.062 %
#   Validation accuracy:  93.000 %
# Epoch 153
#   Loss    :  0.147	  Accuracy:  95.781 %
#   Validation accuracy:  94.000 %
# Epoch 154
#   Loss    :  0.125	  Accuracy:  96.250 %
#   Validation accuracy:  96.000 %
# Epoch 155
#   Loss    :  0.143	  Accuracy:  95.938 %
#   Validation accuracy:  91.000 %
# Epoch 156
#   Loss    :  0.159	  Accuracy:  96.406 %
#   Validation accuracy:  88.000 %
# Epoch 157
#   Loss    :  0.147	  Accuracy:  95.156 %
#   Validation accuracy:  93.000 %
# Epoch 158
#   Loss    :  0.128	  Accuracy:  95.938 %
#   Validation accuracy:  95.000 %
# Epoch 159
#   Loss    :  0.117	  Accuracy:  97.344 %
#   Validation accuracy:  95.000 %
# Epoch 160
#   Loss    :  0.150	  Accuracy:  95.000 %
#   Validation accuracy:  96.000 %
# Epoch 161
#   Loss    :  0.119	  Accuracy:  96.875 %
#   Validation accuracy:  94.000 %
# Epoch 162
#   Loss    :  0.116	  Accuracy:  96.094 %
#   Validation accuracy:  96.000 %
# Epoch 163
#   Loss    :  0.133	  Accuracy:  95.156 %
#   Validation accuracy:  94.000 %
# Epoch 164
#   Loss    :  0.140	  Accuracy:  94.531 %
#   Validation accuracy:  97.000 %
# Epoch 165
#   Loss    :  0.128	  Accuracy:  96.094 %
#   Validation accuracy:  91.000 %
# Epoch 166
#   Loss    :  0.114	  Accuracy:  97.500 %
#   Validation accuracy:  94.000 %
# Epoch 167
#   Loss    :  0.121	  Accuracy:  95.312 %
#   Validation accuracy:  98.000 %
# Epoch 168
#   Loss    :  0.156	  Accuracy:  93.906 %
#   Validation accuracy:  96.000 %
# Epoch 169
#   Loss    :  0.150	  Accuracy:  95.312 %
#   Validation accuracy:  98.000 %
# Epoch 170
#   Loss    :  0.143	  Accuracy:  95.156 %
#   Validation accuracy:  95.000 %
# Epoch 171
#   Loss    :  0.144	  Accuracy:  95.156 %
#   Validation accuracy:  100.000 %
# Epoch 172
#   Loss    :  0.149	  Accuracy:  95.312 %
#   Validation accuracy:  98.000 %
# Epoch 173
#   Loss    :  0.116	  Accuracy:  96.094 %
#   Validation accuracy:  93.000 %
# Epoch 174
#   Loss    :  0.130	  Accuracy:  95.156 %
#   Validation accuracy:  98.000 %
# Epoch 175
#   Loss    :  0.139	  Accuracy:  95.312 %
#   Validation accuracy:  98.000 %
# Epoch 176
#   Loss    :  0.131	  Accuracy:  96.094 %
#   Validation accuracy:  91.000 %
# Epoch 177
#   Loss    :  0.123	  Accuracy:  95.938 %
#   Validation accuracy:  91.000 %
# Epoch 178
#   Loss    :  0.122	  Accuracy:  96.094 %
#   Validation accuracy:  92.000 %
# Epoch 179
#   Loss    :  0.150	  Accuracy:  94.687 %
#   Validation accuracy:  94.000 %
# Epoch 180
#   Loss    :  0.136	  Accuracy:  95.625 %
#   Validation accuracy:  95.000 %
# Epoch 181
#   Loss    :  0.127	  Accuracy:  96.875 %
#   Validation accuracy:  92.000 %
# Epoch 182
#   Loss    :  0.135	  Accuracy:  96.094 %
#   Validation accuracy:  99.000 %
# Epoch 183
#   Loss    :  0.118	  Accuracy:  96.719 %
#   Validation accuracy:  99.000 %
# Epoch 184
#   Loss    :  0.123	  Accuracy:  96.094 %
#   Validation accuracy:  90.000 %
# Epoch 185
#   Loss    :  0.126	  Accuracy:  96.406 %
#   Validation accuracy:  97.000 %
# Epoch 186
#   Loss    :  0.110	  Accuracy:  97.031 %
#   Validation accuracy:  95.000 %
# Epoch 187
#   Loss    :  0.119	  Accuracy:  95.938 %
#   Validation accuracy:  96.000 %
# Epoch 188
#   Loss    :  0.131	  Accuracy:  95.312 %
#   Validation accuracy:  94.000 %
# Epoch 189
#   Loss    :  0.111	  Accuracy:  96.875 %
#   Validation accuracy:  93.000 %
# Epoch 190
#   Loss    :  0.139	  Accuracy:  95.469 %
#   Validation accuracy:  95.000 %
# Epoch 191
#   Loss    :  0.111	  Accuracy:  97.031 %
#   Validation accuracy:  97.000 %
# Epoch 192
#   Loss    :  0.113	  Accuracy:  96.406 %
#   Validation accuracy:  95.000 %
# Epoch 193
#   Loss    :  0.105	  Accuracy:  96.406 %
#   Validation accuracy:  93.000 %
# Epoch 194
#   Loss    :  0.102	  Accuracy:  97.344 %
#   Validation accuracy:  99.000 %
# Epoch 195
#   Loss    :  0.114	  Accuracy:  96.250 %
#   Validation accuracy:  93.000 %
# Epoch 196
#   Loss    :  0.099	  Accuracy:  97.500 %
#   Validation accuracy:  97.000 %
# Epoch 197
#   Loss    :  0.107	  Accuracy:  96.562 %
#   Validation accuracy:  98.000 %
# Epoch 198
#   Loss    :  0.106	  Accuracy:  96.875 %
#   Validation accuracy:  99.000 %
# Epoch 199
#   Loss    :  0.095	  Accuracy:  97.500 %
#   Validation accuracy:  91.000 %
# Epoch 200
#   Loss    :  0.119	  Accuracy:  96.250 %
#   Validation accuracy:  97.000 %
# Epoch 201
#   Loss    :  0.104	  Accuracy:  97.031 %
#   Validation accuracy:  95.000 %
# Epoch 202
#   Loss    :  0.098	  Accuracy:  96.875 %
#   Validation accuracy:  93.000 %
# Epoch 203
#   Loss    :  0.088	  Accuracy:  96.875 %
#   Validation accuracy:  96.000 %
# Epoch 204
#   Loss    :  0.097	  Accuracy:  97.031 %
#   Validation accuracy:  97.000 %
# Epoch 205
#   Loss    :  0.096	  Accuracy:  96.719 %
#   Validation accuracy:  97.000 %
# Epoch 206
#   Loss    :  0.104	  Accuracy:  96.250 %
#   Validation accuracy:  98.000 %
# Epoch 207
#   Loss    :  0.118	  Accuracy:  96.250 %
#   Validation accuracy:  93.000 %
# Epoch 208
#   Loss    :  0.113	  Accuracy:  96.875 %
#   Validation accuracy:  95.000 %
# Epoch 209
#   Loss    :  0.085	  Accuracy:  97.344 %
#   Validation accuracy:  94.000 %
# Epoch 210
#   Loss    :  0.107	  Accuracy:  96.875 %
#   Validation accuracy:  96.000 %
# Epoch 211
#   Loss    :  0.097	  Accuracy:  97.188 %
#   Validation accuracy:  98.000 %
# Epoch 212
#   Loss    :  0.091	  Accuracy:  97.188 %
#   Validation accuracy:  93.000 %
# Epoch 213
#   Loss    :  0.110	  Accuracy:  95.938 %
#   Validation accuracy:  96.000 %
# Epoch 214
#   Loss    :  0.095	  Accuracy:  96.406 %
#   Validation accuracy:  94.000 %
# Epoch 215
#   Loss    :  0.118	  Accuracy:  95.938 %
#   Validation accuracy:  92.000 %
# Epoch 216
#   Loss    :  0.089	  Accuracy:  97.500 %
#   Validation accuracy:  93.000 %
# Epoch 217
#   Loss    :  0.106	  Accuracy:  96.250 %
#   Validation accuracy:  99.000 %
# Epoch 218
#   Loss    :  0.078	  Accuracy:  98.438 %
#   Validation accuracy:  100.000 %
# Epoch 219
#   Loss    :  0.095	  Accuracy:  97.188 %
#   Validation accuracy:  97.000 %
# Epoch 220
#   Loss    :  0.084	  Accuracy:  97.344 %
#   Validation accuracy:  99.000 %
# Epoch 221
#   Loss    :  0.089	  Accuracy:  97.344 %
#   Validation accuracy:  99.000 %
# Epoch 222
#   Loss    :  0.107	  Accuracy:  96.250 %
#   Validation accuracy:  92.000 %
# Epoch 223
#   Loss    :  0.101	  Accuracy:  97.031 %
#   Validation accuracy:  97.000 %
# Epoch 224
#   Loss    :  0.113	  Accuracy:  96.406 %
#   Validation accuracy:  96.000 %
# Epoch 225
#   Loss    :  0.087	  Accuracy:  97.812 %
#   Validation accuracy:  95.000 %
# Epoch 226
#   Loss    :  0.111	  Accuracy:  96.094 %
#   Validation accuracy:  91.000 %
# Epoch 227
#   Loss    :  0.109	  Accuracy:  96.875 %
#   Validation accuracy:  99.000 %
# Epoch 228
#   Loss    :  0.085	  Accuracy:  97.500 %
#   Validation accuracy:  96.000 %
# Epoch 229
#   Loss    :  0.096	  Accuracy:  97.500 %
#   Validation accuracy:  96.000 %
# Epoch 230
#   Loss    :  0.078	  Accuracy:  97.500 %
#   Validation accuracy:  98.000 %
# Epoch 231
#   Loss    :  0.115	  Accuracy:  96.250 %
#   Validation accuracy:  100.000 %
# Epoch 232
#   Loss    :  0.073	  Accuracy:  98.281 %
#   Validation accuracy:  95.000 %
# Epoch 233
#   Loss    :  0.092	  Accuracy:  97.344 %
#   Validation accuracy:  96.000 %
# Epoch 234
#   Loss    :  0.098	  Accuracy:  96.719 %
#   Validation accuracy:  98.000 %
# Epoch 235
#   Loss    :  0.077	  Accuracy:  97.656 %
#   Validation accuracy:  94.000 %
# Epoch 236
#   Loss    :  0.079	  Accuracy:  97.500 %
#   Validation accuracy:  96.000 %
# Epoch 237
#   Loss    :  0.092	  Accuracy:  96.875 %
#   Validation accuracy:  95.000 %
# Epoch 238
#   Loss    :  0.085	  Accuracy:  97.656 %
#   Validation accuracy:  90.000 %
# Epoch 239
#   Loss    :  0.089	  Accuracy:  96.875 %
#   Validation accuracy:  100.000 %
# Epoch 240
#   Loss    :  0.081	  Accuracy:  98.281 %
#   Validation accuracy:  96.000 %
# Epoch 241
#   Loss    :  0.082	  Accuracy:  97.500 %
#   Validation accuracy:  95.000 %
# Epoch 242
#   Loss    :  0.092	  Accuracy:  96.250 %
#   Validation accuracy:  95.000 %
# Epoch 243
#   Loss    :  0.095	  Accuracy:  96.562 %
#   Validation accuracy:  96.000 %
# Epoch 244
#   Loss    :  0.097	  Accuracy:  97.344 %
#   Validation accuracy:  98.000 %
# Epoch 245
#   Loss    :  0.105	  Accuracy:  96.250 %
#   Validation accuracy:  98.000 %
# Epoch 246
#   Loss    :  0.079	  Accuracy:  97.500 %
#   Validation accuracy:  90.000 %
# Epoch 247
#   Loss    :  0.076	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 248
#   Loss    :  0.084	  Accuracy:  97.969 %
#   Validation accuracy:  99.000 %
# Epoch 249
#   Loss    :  0.065	  Accuracy:  98.125 %
#   Validation accuracy:  98.000 %
# Epoch 250
#   Loss    :  0.070	  Accuracy:  97.500 %
#   Validation accuracy:  94.000 %
# Epoch 251
#   Loss    :  0.107	  Accuracy:  96.875 %
#   Validation accuracy:  98.000 %
# Epoch 252
#   Loss    :  0.080	  Accuracy:  97.656 %
#   Validation accuracy:  95.000 %
# Epoch 253
#   Loss    :  0.078	  Accuracy:  97.188 %
#   Validation accuracy:  97.000 %
# Epoch 254
#   Loss    :  0.084	  Accuracy:  97.188 %
#   Validation accuracy:  98.000 %
# Epoch 255
#   Loss    :  0.083	  Accuracy:  97.812 %
#   Validation accuracy:  94.000 %
# Epoch 256
#   Loss    :  0.090	  Accuracy:  96.406 %
#   Validation accuracy:  96.000 %
# Epoch 257
#   Loss    :  0.092	  Accuracy:  96.719 %
#   Validation accuracy:  90.000 %
# Epoch 258
#   Loss    :  0.106	  Accuracy:  96.875 %
#   Validation accuracy:  98.000 %
# Epoch 259
#   Loss    :  0.084	  Accuracy:  97.656 %
#   Validation accuracy:  96.000 %
# Epoch 260
#   Loss    :  0.080	  Accuracy:  98.281 %
#   Validation accuracy:  97.000 %
# Epoch 261
#   Loss    :  0.081	  Accuracy:  97.500 %
#   Validation accuracy:  98.000 %
# Epoch 262
#   Loss    :  0.089	  Accuracy:  97.031 %
#   Validation accuracy:  98.000 %
# Epoch 263
#   Loss    :  0.081	  Accuracy:  97.812 %
#   Validation accuracy:  99.000 %
# Epoch 264
#   Loss    :  0.088	  Accuracy:  97.344 %
#   Validation accuracy:  99.000 %
# Epoch 265
#   Loss    :  0.075	  Accuracy:  97.969 %
#   Validation accuracy:  96.000 %
# Epoch 266
#   Loss    :  0.074	  Accuracy:  97.969 %
#   Validation accuracy:  96.000 %
# Epoch 267
#   Loss    :  0.078	  Accuracy:  97.500 %
#   Validation accuracy:  97.000 %
# Epoch 268
#   Loss    :  0.069	  Accuracy:  98.438 %
#   Validation accuracy:  97.000 %
# Epoch 269
#   Loss    :  0.098	  Accuracy:  96.719 %
#   Validation accuracy:  98.000 %
# Epoch 270
#   Loss    :  0.097	  Accuracy:  97.344 %
#   Validation accuracy:  96.000 %
# Epoch 271
#   Loss    :  0.069	  Accuracy:  98.125 %
#   Validation accuracy:  98.000 %
# Epoch 272
#   Loss    :  0.094	  Accuracy:  96.875 %
#   Validation accuracy:  96.000 %
# Epoch 273
#   Loss    :  0.066	  Accuracy:  98.281 %
#   Validation accuracy:  97.000 %
# Epoch 274
#   Loss    :  0.065	  Accuracy:  98.438 %
#   Validation accuracy:  96.000 %
# Epoch 275
#   Loss    :  0.081	  Accuracy:  97.500 %
#   Validation accuracy:  97.000 %
# Epoch 276
#   Loss    :  0.083	  Accuracy:  97.656 %
#   Validation accuracy:  99.000 %
# Epoch 277
#   Loss    :  0.066	  Accuracy:  97.969 %
#   Validation accuracy:  98.000 %
# Epoch 278
#   Loss    :  0.075	  Accuracy:  97.656 %
#   Validation accuracy:  96.000 %
# Epoch 279
#   Loss    :  0.066	  Accuracy:  98.125 %
#   Validation accuracy:  97.000 %
# Epoch 280
#   Loss    :  0.076	  Accuracy:  97.656 %
#   Validation accuracy:  95.000 %
# Epoch 281
#   Loss    :  0.073	  Accuracy:  97.812 %
#   Validation accuracy:  93.000 %
# Epoch 282
#   Loss    :  0.086	  Accuracy:  97.188 %
#   Validation accuracy:  93.000 %
# Epoch 283
#   Loss    :  0.079	  Accuracy:  97.656 %
#   Validation accuracy:  97.000 %
# Epoch 284
#   Loss    :  0.072	  Accuracy:  97.969 %
#   Validation accuracy:  94.000 %
# Epoch 285
#   Loss    :  0.082	  Accuracy:  97.656 %
#   Validation accuracy:  100.000 %
# Epoch 286
#   Loss    :  0.095	  Accuracy:  96.562 %
#   Validation accuracy:  100.000 %
# Epoch 287
#   Loss    :  0.061	  Accuracy:  98.438 %
#   Validation accuracy:  97.000 %
# Epoch 288
#   Loss    :  0.075	  Accuracy:  97.344 %
#   Validation accuracy:  92.000 %
# Epoch 289
#   Loss    :  0.081	  Accuracy:  97.969 %
#   Validation accuracy:  98.000 %
# Epoch 290
#   Loss    :  0.075	  Accuracy:  97.344 %
#   Validation accuracy:  96.000 %
# Epoch 291
#   Loss    :  0.069	  Accuracy:  97.188 %
#   Validation accuracy:  98.000 %
# Epoch 292
#   Loss    :  0.070	  Accuracy:  97.812 %
#   Validation accuracy:  97.000 %
# Epoch 293
#   Loss    :  0.071	  Accuracy:  98.125 %
#   Validation accuracy:  97.000 %
# Epoch 294
#   Loss    :  0.057	  Accuracy:  98.281 %
#   Validation accuracy:  96.000 %
# Epoch 295
#   Loss    :  0.063	  Accuracy:  98.438 %
#   Validation accuracy:  98.000 %
# Epoch 296
#   Loss    :  0.075	  Accuracy:  97.344 %
#   Validation accuracy:  98.000 %
# Epoch 297
#   Loss    :  0.059	  Accuracy:  97.812 %
#   Validation accuracy:  98.000 %
# Epoch 298
#   Loss    :  0.062	  Accuracy:  97.969 %
#   Validation accuracy:  94.000 %
# Epoch 299
#   Loss    :  0.063	  Accuracy:  98.281 %
#   Validation accuracy:  94.000 %
# Epoch 300
#   Loss    :  0.073	  Accuracy:  97.812 %
#   Validation accuracy:  95.000 %
# Epoch 301
#   Loss    :  0.092	  Accuracy:  96.406 %
#   Validation accuracy:  96.000 %
# Epoch 302
#   Loss    :  0.067	  Accuracy:  97.969 %
#   Validation accuracy:  99.000 %
# Epoch 303
#   Loss    :  0.070	  Accuracy:  98.125 %
#   Validation accuracy:  99.000 %
# Epoch 304
#   Loss    :  0.072	  Accuracy:  98.438 %
#   Validation accuracy:  96.000 %
# Epoch 305
#   Loss    :  0.081	  Accuracy:  97.656 %
#   Validation accuracy:  98.000 %
# Epoch 306
#   Loss    :  0.071	  Accuracy:  97.656 %
#   Validation accuracy:  96.000 %
# Epoch 307
#   Loss    :  0.049	  Accuracy:  98.594 %
#   Validation accuracy:  98.000 %
# Epoch 308
#   Loss    :  0.076	  Accuracy:  97.188 %
#   Validation accuracy:  98.000 %
# Epoch 309
#   Loss    :  0.082	  Accuracy:  97.656 %
#   Validation accuracy:  96.000 %
# Epoch 310
#   Loss    :  0.062	  Accuracy:  98.125 %
#   Validation accuracy:  96.000 %
# Epoch 311
#   Loss    :  0.066	  Accuracy:  97.656 %
#   Validation accuracy:  94.000 %
# Epoch 312
#   Loss    :  0.067	  Accuracy:  97.656 %
#   Validation accuracy:  100.000 %
# Epoch 313
#   Loss    :  0.080	  Accuracy:  97.500 %
#   Validation accuracy:  100.000 %
# Epoch 314
#   Loss    :  0.062	  Accuracy:  98.594 %
#   Validation accuracy:  95.000 %
# Epoch 315
#   Loss    :  0.095	  Accuracy:  96.562 %
#   Validation accuracy:  98.000 %
# Epoch 316
#   Loss    :  0.077	  Accuracy:  98.125 %
#   Validation accuracy:  97.000 %
# Epoch 317
#   Loss    :  0.075	  Accuracy:  97.500 %
#   Validation accuracy:  99.000 %
# Epoch 318
#   Loss    :  0.067	  Accuracy:  97.031 %
#   Validation accuracy:  97.000 %
# Epoch 319
#   Loss    :  0.059	  Accuracy:  98.281 %
#   Validation accuracy:  98.000 %
# Epoch 320
#   Loss    :  0.092	  Accuracy:  96.406 %
#   Validation accuracy:  95.000 %
# Epoch 321
#   Loss    :  0.074	  Accuracy:  97.812 %
#   Validation accuracy:  98.000 %
# Epoch 322
#   Loss    :  0.056	  Accuracy:  98.125 %
#   Validation accuracy:  98.000 %
# Epoch 323
#   Loss    :  0.047	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 324
#   Loss    :  0.059	  Accuracy:  98.438 %
#   Validation accuracy:  96.000 %
# Epoch 325
#   Loss    :  0.070	  Accuracy:  97.656 %
#   Validation accuracy:  94.000 %
# Epoch 326
#   Loss    :  0.062	  Accuracy:  97.656 %
#   Validation accuracy:  99.000 %
# Epoch 327
#   Loss    :  0.061	  Accuracy:  97.969 %
#   Validation accuracy:  97.000 %
# Epoch 328
#   Loss    :  0.064	  Accuracy:  97.812 %
#   Validation accuracy:  97.000 %
# Epoch 329
#   Loss    :  0.070	  Accuracy:  98.281 %
#   Validation accuracy:  97.000 %
# Epoch 330
#   Loss    :  0.058	  Accuracy:  98.594 %
#   Validation accuracy:  96.000 %
# Epoch 331
#   Loss    :  0.065	  Accuracy:  97.969 %
#   Validation accuracy:  98.000 %
# Epoch 332
#   Loss    :  0.071	  Accuracy:  96.562 %
#   Validation accuracy:  98.000 %
# Epoch 333
#   Loss    :  0.048	  Accuracy:  98.750 %
#   Validation accuracy:  94.000 %
# Epoch 334
#   Loss    :  0.078	  Accuracy:  97.969 %
#   Validation accuracy:  100.000 %
# Epoch 335
#   Loss    :  0.058	  Accuracy:  97.813 %
#   Validation accuracy:  99.000 %
# Epoch 336
#   Loss    :  0.059	  Accuracy:  98.125 %
#   Validation accuracy:  97.000 %
# Epoch 337
#   Loss    :  0.063	  Accuracy:  97.969 %
#   Validation accuracy:  98.000 %
# Epoch 338
#   Loss    :  0.063	  Accuracy:  98.125 %
#   Validation accuracy:  98.000 %
# Epoch 339
#   Loss    :  0.071	  Accuracy:  98.125 %
#   Validation accuracy:  99.000 %
# Epoch 340
#   Loss    :  0.076	  Accuracy:  97.188 %
#   Validation accuracy:  98.000 %
# Epoch 341
#   Loss    :  0.059	  Accuracy:  98.125 %
#   Validation accuracy:  94.000 %
# Epoch 342
#   Loss    :  0.089	  Accuracy:  97.031 %
#   Validation accuracy:  95.000 %
# Epoch 343
#   Loss    :  0.063	  Accuracy:  98.125 %
#   Validation accuracy:  97.000 %
# Epoch 344
#   Loss    :  0.063	  Accuracy:  98.281 %
#   Validation accuracy:  98.000 %
# Epoch 345
#   Loss    :  0.060	  Accuracy:  98.594 %
#   Validation accuracy:  95.000 %
# Epoch 346
#   Loss    :  0.081	  Accuracy:  96.875 %
#   Validation accuracy:  97.000 %
# Epoch 347
#   Loss    :  0.066	  Accuracy:  97.969 %
#   Validation accuracy:  99.000 %
# Epoch 348
#   Loss    :  0.093	  Accuracy:  96.562 %
#   Validation accuracy:  97.000 %
# Epoch 349
#   Loss    :  0.066	  Accuracy:  97.969 %
#   Validation accuracy:  98.000 %
# Epoch 350
#   Loss    :  0.083	  Accuracy:  97.031 %
#   Validation accuracy:  98.000 %
# Epoch 351
#   Loss    :  0.067	  Accuracy:  98.125 %
#   Validation accuracy:  98.000 %
# Epoch 352
#   Loss    :  0.084	  Accuracy:  96.875 %
#   Validation accuracy:  99.000 %
# Epoch 353
#   Loss    :  0.059	  Accuracy:  98.281 %
#   Validation accuracy:  98.000 %
# Epoch 354
#   Loss    :  0.090	  Accuracy:  96.719 %
#   Validation accuracy:  99.000 %
# Epoch 355
#   Loss    :  0.074	  Accuracy:  97.812 %
#   Validation accuracy:  97.000 %
# Epoch 356
#   Loss    :  0.080	  Accuracy:  97.500 %
#   Validation accuracy:  97.000 %
# Epoch 357
#   Loss    :  0.064	  Accuracy:  98.281 %
#   Validation accuracy:  94.000 %
# Epoch 358
#   Loss    :  0.075	  Accuracy:  96.875 %
#   Validation accuracy:  98.000 %
# Epoch 359
#   Loss    :  0.053	  Accuracy:  98.906 %
#   Validation accuracy:  96.000 %
# Epoch 360
#   Loss    :  0.054	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 361
#   Loss    :  0.064	  Accuracy:  98.438 %
#   Validation accuracy:  98.000 %
# Epoch 362
#   Loss    :  0.073	  Accuracy:  97.344 %
#   Validation accuracy:  95.000 %
# Epoch 363
#   Loss    :  0.073	  Accuracy:  97.812 %
#   Validation accuracy:  100.000 %
# Epoch 364
#   Loss    :  0.042	  Accuracy:  98.906 %
#   Validation accuracy:  95.000 %
# Epoch 365
#   Loss    :  0.084	  Accuracy:  97.188 %
#   Validation accuracy:  99.000 %
# Epoch 366
#   Loss    :  0.067	  Accuracy:  98.125 %
#   Validation accuracy:  100.000 %
# Epoch 367
#   Loss    :  0.063	  Accuracy:  98.125 %
#   Validation accuracy:  95.000 %
# Epoch 368
#   Loss    :  0.050	  Accuracy:  98.906 %
#   Validation accuracy:  97.000 %
# Epoch 369
#   Loss    :  0.066	  Accuracy:  97.500 %
#   Validation accuracy:  94.000 %
# Epoch 370
#   Loss    :  0.063	  Accuracy:  97.812 %
#   Validation accuracy:  97.000 %
# Epoch 371
#   Loss    :  0.038	  Accuracy:  98.750 %
#   Validation accuracy:  97.000 %
# Epoch 372
#   Loss    :  0.045	  Accuracy:  98.438 %
#   Validation accuracy:  98.000 %
# Epoch 373
#   Loss    :  0.060	  Accuracy:  97.969 %
#   Validation accuracy:  100.000 %
# Epoch 374
#   Loss    :  0.072	  Accuracy:  97.812 %
#   Validation accuracy:  98.000 %
# Epoch 375
#   Loss    :  0.054	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 376
#   Loss    :  0.069	  Accuracy:  97.969 %
#   Validation accuracy:  97.000 %
# Epoch 377
#   Loss    :  0.056	  Accuracy:  98.125 %
#   Validation accuracy:  96.000 %
# Epoch 378
#   Loss    :  0.071	  Accuracy:  97.188 %
#   Validation accuracy:  99.000 %
# Epoch 379
#   Loss    :  0.054	  Accuracy:  98.906 %
#   Validation accuracy:  97.000 %
# Epoch 380
#   Loss    :  0.056	  Accuracy:  98.281 %
#   Validation accuracy:  100.000 %
# Epoch 381
#   Loss    :  0.073	  Accuracy:  98.125 %
#   Validation accuracy:  96.000 %
# Epoch 382
#   Loss    :  0.043	  Accuracy:  98.750 %
#   Validation accuracy:  99.000 %
# Epoch 383
#   Loss    :  0.064	  Accuracy:  97.500 %
#   Validation accuracy:  98.000 %
# Epoch 384
#   Loss    :  0.052	  Accuracy:  98.438 %
#   Validation accuracy:  97.000 %
# Epoch 385
#   Loss    :  0.064	  Accuracy:  98.281 %
#   Validation accuracy:  98.000 %
# Epoch 386
#   Loss    :  0.054	  Accuracy:  98.594 %
#   Validation accuracy:  97.000 %
# Epoch 387
#   Loss    :  0.059	  Accuracy:  97.656 %
#   Validation accuracy:  94.000 %
# Epoch 388
#   Loss    :  0.058	  Accuracy:  98.281 %
#   Validation accuracy:  98.000 %
# Epoch 389
#   Loss    :  0.060	  Accuracy:  98.438 %
#   Validation accuracy:  99.000 %
# Epoch 390
#   Loss    :  0.050	  Accuracy:  98.750 %
#   Validation accuracy:  99.000 %
# Epoch 391
#   Loss    :  0.062	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 392
#   Loss    :  0.068	  Accuracy:  97.969 %
#   Validation accuracy:  98.000 %
# Epoch 393
#   Loss    :  0.056	  Accuracy:  98.281 %
#   Validation accuracy:  97.000 %
# Epoch 394
#   Loss    :  0.061	  Accuracy:  98.281 %
#   Validation accuracy:  97.000 %
# Epoch 395
#   Loss    :  0.066	  Accuracy:  97.188 %
#   Validation accuracy:  97.000 %
# Epoch 396
#   Loss    :  0.066	  Accuracy:  97.656 %
#   Validation accuracy:  99.000 %
# Epoch 397
#   Loss    :  0.062	  Accuracy:  97.656 %
#   Validation accuracy:  97.000 %
# Epoch 398
#   Loss    :  0.046	  Accuracy:  99.219 %
#   Validation accuracy:  96.000 %
# Epoch 399
#   Loss    :  0.050	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 400
#   Loss    :  0.050	  Accuracy:  98.438 %
#   Validation accuracy:  97.000 %
# Epoch 401
#   Loss    :  0.034	  Accuracy:  99.062 %
#   Validation accuracy:  96.000 %
# Epoch 402
#   Loss    :  0.065	  Accuracy:  97.500 %
#   Validation accuracy:  97.000 %
# Epoch 403
#   Loss    :  0.064	  Accuracy:  97.812 %
#   Validation accuracy:  99.000 %
# Epoch 404
#   Loss    :  0.038	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 405
#   Loss    :  0.057	  Accuracy:  98.438 %
#   Validation accuracy:  98.000 %
# Epoch 406
#   Loss    :  0.052	  Accuracy:  98.750 %
#   Validation accuracy:  96.000 %
# Epoch 407
#   Loss    :  0.064	  Accuracy:  97.969 %
#   Validation accuracy:  99.000 %
# Epoch 408
#   Loss    :  0.047	  Accuracy:  98.125 %
#   Validation accuracy:  100.000 %
# Epoch 409
#   Loss    :  0.070	  Accuracy:  97.813 %
#   Validation accuracy:  99.000 %
# Epoch 410
#   Loss    :  0.064	  Accuracy:  97.656 %
#   Validation accuracy:  98.000 %
# Epoch 411
#   Loss    :  0.050	  Accuracy:  98.594 %
#   Validation accuracy:  100.000 %
# Epoch 412
#   Loss    :  0.064	  Accuracy:  97.344 %
#   Validation accuracy:  91.000 %
# Epoch 413
#   Loss    :  0.067	  Accuracy:  97.969 %
#   Validation accuracy:  97.000 %
# Epoch 414
#   Loss    :  0.062	  Accuracy:  98.125 %
#   Validation accuracy:  97.000 %
# Epoch 415
#   Loss    :  0.051	  Accuracy:  99.063 %
#   Validation accuracy:  99.000 %
# Epoch 416
#   Loss    :  0.073	  Accuracy:  97.500 %
#   Validation accuracy:  95.000 %
# Epoch 417
#   Loss    :  0.047	  Accuracy:  98.438 %
#   Validation accuracy:  93.000 %
# Epoch 418
#   Loss    :  0.053	  Accuracy:  98.125 %
#   Validation accuracy:  97.000 %
# Epoch 419
#   Loss    :  0.059	  Accuracy:  97.969 %
#   Validation accuracy:  98.000 %
# Epoch 420
#   Loss    :  0.045	  Accuracy:  98.750 %
#   Validation accuracy:  96.000 %
# Epoch 421
#   Loss    :  0.049	  Accuracy:  98.750 %
#   Validation accuracy:  97.000 %
# Epoch 422
#   Loss    :  0.042	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 423
#   Loss    :  0.080	  Accuracy:  97.656 %
#   Validation accuracy:  97.000 %
# Epoch 424
#   Loss    :  0.055	  Accuracy:  98.281 %
#   Validation accuracy:  98.000 %
# Epoch 425
#   Loss    :  0.074	  Accuracy:  96.719 %
#   Validation accuracy:  99.000 %
# Epoch 426
#   Loss    :  0.077	  Accuracy:  97.031 %
#   Validation accuracy:  98.000 %
# Epoch 427
#   Loss    :  0.069	  Accuracy:  98.281 %
#   Validation accuracy:  97.000 %
# Epoch 428
#   Loss    :  0.051	  Accuracy:  98.438 %
#   Validation accuracy:  94.000 %
# Epoch 429
#   Loss    :  0.041	  Accuracy:  98.438 %
#   Validation accuracy:  97.000 %
# Epoch 430
#   Loss    :  0.053	  Accuracy:  98.281 %
#   Validation accuracy:  95.000 %
# Epoch 431
#   Loss    :  0.052	  Accuracy:  98.281 %
#   Validation accuracy:  99.000 %
# Epoch 432
#   Loss    :  0.037	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 433
#   Loss    :  0.042	  Accuracy:  98.594 %
#   Validation accuracy:  98.000 %
# Epoch 434
#   Loss    :  0.037	  Accuracy:  99.219 %
#   Validation accuracy:  96.000 %
# Epoch 435
#   Loss    :  0.043	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 436
#   Loss    :  0.058	  Accuracy:  98.281 %
#   Validation accuracy:  98.000 %
# Epoch 437
#   Loss    :  0.046	  Accuracy:  98.594 %
#   Validation accuracy:  98.000 %
# Epoch 438
#   Loss    :  0.051	  Accuracy:  98.750 %
#   Validation accuracy:  99.000 %
# Epoch 439
#   Loss    :  0.066	  Accuracy:  97.656 %
#   Validation accuracy:  100.000 %
# Epoch 440
#   Loss    :  0.053	  Accuracy:  98.750 %
#   Validation accuracy:  98.000 %
# Epoch 441
#   Loss    :  0.061	  Accuracy:  97.656 %
#   Validation accuracy:  98.000 %
# Epoch 442
#   Loss    :  0.041	  Accuracy:  98.906 %
#   Validation accuracy:  97.000 %
# Epoch 443
#   Loss    :  0.051	  Accuracy:  98.281 %
#   Validation accuracy:  98.000 %
# Epoch 444
#   Loss    :  0.068	  Accuracy:  97.656 %
#   Validation accuracy:  99.000 %
# Epoch 445
#   Loss    :  0.038	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 446
#   Loss    :  0.068	  Accuracy:  97.656 %
#   Validation accuracy:  96.000 %
# Epoch 447
#   Loss    :  0.068	  Accuracy:  97.188 %
#   Validation accuracy:  98.000 %
# Epoch 448
#   Loss    :  0.052	  Accuracy:  97.969 %
#   Validation accuracy:  100.000 %
# Epoch 449
#   Loss    :  0.047	  Accuracy:  98.906 %
#   Validation accuracy:  99.000 %
# Epoch 450
#   Loss    :  0.056	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 451
#   Loss    :  0.057	  Accuracy:  98.750 %
#   Validation accuracy:  98.000 %
# Epoch 452
#   Loss    :  0.055	  Accuracy:  97.656 %
#   Validation accuracy:  100.000 %
# Epoch 453
#   Loss    :  0.033	  Accuracy:  99.531 %
#   Validation accuracy:  100.000 %
# Epoch 454
#   Loss    :  0.064	  Accuracy:  97.656 %
#   Validation accuracy:  99.000 %
# Epoch 455
#   Loss    :  0.039	  Accuracy:  98.594 %
#   Validation accuracy:  92.000 %
# Epoch 456
#   Loss    :  0.068	  Accuracy:  97.812 %
#   Validation accuracy:  98.000 %
# Epoch 457
#   Loss    :  0.054	  Accuracy:  97.812 %
#   Validation accuracy:  98.000 %
# Epoch 458
#   Loss    :  0.036	  Accuracy:  99.063 %
#   Validation accuracy:  99.000 %
# Epoch 459
#   Loss    :  0.043	  Accuracy:  98.906 %
#   Validation accuracy:  97.000 %
# Epoch 460
#   Loss    :  0.057	  Accuracy:  97.500 %
#   Validation accuracy:  99.000 %
# Epoch 461
#   Loss    :  0.033	  Accuracy:  99.531 %
#   Validation accuracy:  99.000 %
# Epoch 462
#   Loss    :  0.057	  Accuracy:  97.812 %
#   Validation accuracy:  99.000 %
# Epoch 463
#   Loss    :  0.051	  Accuracy:  98.437 %
#   Validation accuracy:  96.000 %
# Epoch 464
#   Loss    :  0.053	  Accuracy:  98.281 %
#   Validation accuracy:  95.000 %
# Epoch 465
#   Loss    :  0.049	  Accuracy:  98.281 %
#   Validation accuracy:  97.000 %
# Epoch 466
#   Loss    :  0.047	  Accuracy:  98.906 %
#   Validation accuracy:  99.000 %
# Epoch 467
#   Loss    :  0.042	  Accuracy:  99.063 %
#   Validation accuracy:  98.000 %
# Epoch 468
#   Loss    :  0.054	  Accuracy:  97.969 %
#   Validation accuracy:  99.000 %
# Epoch 469
#   Loss    :  0.053	  Accuracy:  97.812 %
#   Validation accuracy:  95.000 %
# Epoch 470
#   Loss    :  0.070	  Accuracy:  97.344 %
#   Validation accuracy:  97.000 %
# Epoch 471
#   Loss    :  0.048	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 472
#   Loss    :  0.049	  Accuracy:  97.812 %
#   Validation accuracy:  99.000 %
# Epoch 473
#   Loss    :  0.054	  Accuracy:  98.906 %
#   Validation accuracy:  94.000 %
# Epoch 474
#   Loss    :  0.058	  Accuracy:  98.281 %
#   Validation accuracy:  97.000 %
# Epoch 475
#   Loss    :  0.038	  Accuracy:  98.906 %
#   Validation accuracy:  97.000 %
# Epoch 476
#   Loss    :  0.049	  Accuracy:  97.969 %
#   Validation accuracy:  96.000 %
# Epoch 477
#   Loss    :  0.060	  Accuracy:  98.438 %
#   Validation accuracy:  98.000 %
# Epoch 478
#   Loss    :  0.050	  Accuracy:  97.969 %
#   Validation accuracy:  97.000 %
# Epoch 479
#   Loss    :  0.057	  Accuracy:  98.125 %
#   Validation accuracy:  99.000 %
# Epoch 480
#   Loss    :  0.054	  Accuracy:  98.438 %
#   Validation accuracy:  98.000 %
# Epoch 481
#   Loss    :  0.044	  Accuracy:  99.375 %
#   Validation accuracy:  100.000 %
# Epoch 482
#   Loss    :  0.053	  Accuracy:  98.281 %
#   Validation accuracy:  98.000 %
# Epoch 483
#   Loss    :  0.044	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 484
#   Loss    :  0.069	  Accuracy:  97.500 %
#   Validation accuracy:  97.000 %
# Epoch 485
#   Loss    :  0.055	  Accuracy:  98.281 %
#   Validation accuracy:  96.000 %
# Epoch 486
#   Loss    :  0.035	  Accuracy:  99.375 %
#   Validation accuracy:  99.000 %
# Epoch 487
#   Loss    :  0.059	  Accuracy:  97.812 %
#   Validation accuracy:  99.000 %
# Epoch 488
#   Loss    :  0.061	  Accuracy:  97.656 %
#   Validation accuracy:  98.000 %
# Epoch 489
#   Loss    :  0.056	  Accuracy:  98.125 %
#   Validation accuracy:  98.000 %
# Epoch 490
#   Loss    :  0.055	  Accuracy:  98.438 %
#   Validation accuracy:  100.000 %
# Epoch 491
#   Loss    :  0.061	  Accuracy:  97.969 %
#   Validation accuracy:  95.000 %
# Epoch 492
#   Loss    :  0.049	  Accuracy:  98.750 %
#   Validation accuracy:  98.000 %
# Epoch 493
#   Loss    :  0.052	  Accuracy:  97.969 %
#   Validation accuracy:  99.000 %
# Epoch 494
#   Loss    :  0.049	  Accuracy:  98.125 %
#   Validation accuracy:  99.000 %
# Epoch 495
#   Loss    :  0.052	  Accuracy:  98.750 %
#   Validation accuracy:  98.000 %
# Epoch 496
#   Loss    :  0.034	  Accuracy:  99.063 %
#   Validation accuracy:  98.000 %
# Epoch 497
#   Loss    :  0.040	  Accuracy:  99.062 %
#   Validation accuracy:  98.000 %
# Epoch 498
#   Loss    :  0.041	  Accuracy:  98.750 %
#   Validation accuracy:  95.000 %
# Epoch 499
#   Loss    :  0.045	  Accuracy:  98.750 %
#   Validation accuracy:  95.000 %
# Epoch 500
#   Loss    :  0.052	  Accuracy:  98.594 %
#   Validation accuracy:  98.000 %
# Epoch 501
#   Loss    :  0.049	  Accuracy:  98.594 %
#   Validation accuracy:  97.000 %
# Epoch 502
#   Loss    :  0.050	  Accuracy:  98.281 %
#   Validation accuracy:  100.000 %
# Epoch 503
#   Loss    :  0.040	  Accuracy:  99.063 %
#   Validation accuracy:  98.000 %
# Epoch 504
#   Loss    :  0.051	  Accuracy:  97.969 %
#   Validation accuracy:  99.000 %
# Epoch 505
#   Loss    :  0.053	  Accuracy:  98.125 %
#   Validation accuracy:  99.000 %
# Epoch 506
#   Loss    :  0.035	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 507
#   Loss    :  0.053	  Accuracy:  98.125 %
#   Validation accuracy:  98.000 %
# Epoch 508
#   Loss    :  0.058	  Accuracy:  98.281 %
#   Validation accuracy:  96.000 %
# Epoch 509
#   Loss    :  0.032	  Accuracy:  99.375 %
#   Validation accuracy:  97.000 %
# Epoch 510
#   Loss    :  0.049	  Accuracy:  98.125 %
#   Validation accuracy:  100.000 %
# Epoch 511
#   Loss    :  0.050	  Accuracy:  98.281 %
#   Validation accuracy:  99.000 %
# Epoch 512
#   Loss    :  0.051	  Accuracy:  98.438 %
#   Validation accuracy:  99.000 %
# Epoch 513
#   Loss    :  0.070	  Accuracy:  98.125 %
#   Validation accuracy:  96.000 %
# Epoch 514
#   Loss    :  0.041	  Accuracy:  98.750 %
#   Validation accuracy:  100.000 %
# Epoch 515
#   Loss    :  0.031	  Accuracy:  99.375 %
#   Validation accuracy:  97.000 %
# Epoch 516
#   Loss    :  0.055	  Accuracy:  97.656 %
#   Validation accuracy:  100.000 %
# Epoch 517
#   Loss    :  0.038	  Accuracy:  98.594 %
#   Validation accuracy:  94.000 %
# Epoch 518
#   Loss    :  0.045	  Accuracy:  98.750 %
#   Validation accuracy:  98.000 %
# Epoch 519
#   Loss    :  0.038	  Accuracy:  99.375 %
#   Validation accuracy:  96.000 %
# Epoch 520
#   Loss    :  0.045	  Accuracy:  98.125 %
#   Validation accuracy:  93.000 %
# Epoch 521
#   Loss    :  0.049	  Accuracy:  97.969 %
#   Validation accuracy:  99.000 %
# Epoch 522
#   Loss    :  0.044	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 523
#   Loss    :  0.041	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 524
#   Loss    :  0.060	  Accuracy:  98.125 %
#   Validation accuracy:  97.000 %
# Epoch 525
#   Loss    :  0.047	  Accuracy:  98.438 %
#   Validation accuracy:  96.000 %
# Epoch 526
#   Loss    :  0.048	  Accuracy:  98.438 %
#   Validation accuracy:  97.000 %
# Epoch 527
#   Loss    :  0.047	  Accuracy:  99.063 %
#   Validation accuracy:  98.000 %
# Epoch 528
#   Loss    :  0.051	  Accuracy:  98.281 %
#   Validation accuracy:  99.000 %
# Epoch 529
#   Loss    :  0.053	  Accuracy:  98.281 %
#   Validation accuracy:  97.000 %
# Epoch 530
#   Loss    :  0.047	  Accuracy:  98.594 %
#   Validation accuracy:  98.000 %
# Epoch 531
#   Loss    :  0.036	  Accuracy:  99.062 %
#   Validation accuracy:  99.000 %
# Epoch 532
#   Loss    :  0.042	  Accuracy:  98.906 %
#   Validation accuracy:  100.000 %
# Epoch 533
#   Loss    :  0.059	  Accuracy:  98.281 %
#   Validation accuracy:  98.000 %
# Epoch 534
#   Loss    :  0.038	  Accuracy:  98.906 %
#   Validation accuracy:  97.000 %
# Epoch 535
#   Loss    :  0.041	  Accuracy:  98.906 %
#   Validation accuracy:  99.000 %
# Epoch 536
#   Loss    :  0.045	  Accuracy:  98.750 %
#   Validation accuracy:  95.000 %
# Epoch 537
#   Loss    :  0.034	  Accuracy:  98.750 %
#   Validation accuracy:  96.000 %
# Epoch 538
#   Loss    :  0.035	  Accuracy:  98.906 %
#   Validation accuracy:  100.000 %
# Epoch 539
#   Loss    :  0.056	  Accuracy:  97.500 %
#   Validation accuracy:  96.000 %
# Epoch 540
#   Loss    :  0.044	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 541
#   Loss    :  0.040	  Accuracy:  99.063 %
#   Validation accuracy:  99.000 %
# Epoch 542
#   Loss    :  0.041	  Accuracy:  98.750 %
#   Validation accuracy:  98.000 %
# Epoch 543
#   Loss    :  0.051	  Accuracy:  97.969 %
#   Validation accuracy:  96.000 %
# Epoch 544
#   Loss    :  0.045	  Accuracy:  98.594 %
#   Validation accuracy:  97.000 %
# Epoch 545
#   Loss    :  0.040	  Accuracy:  98.750 %
#   Validation accuracy:  99.000 %
# Epoch 546
#   Loss    :  0.041	  Accuracy:  98.750 %
#   Validation accuracy:  95.000 %
# Epoch 547
#   Loss    :  0.045	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 548
#   Loss    :  0.040	  Accuracy:  98.750 %
#   Validation accuracy:  99.000 %
# Epoch 549
#   Loss    :  0.032	  Accuracy:  99.219 %
#   Validation accuracy:  96.000 %
# Epoch 550
#   Loss    :  0.044	  Accuracy:  98.750 %
#   Validation accuracy:  97.000 %
# Epoch 551
#   Loss    :  0.060	  Accuracy:  97.969 %
#   Validation accuracy:  99.000 %
# Epoch 552
#   Loss    :  0.061	  Accuracy:  98.281 %
#   Validation accuracy:  97.000 %
# Epoch 553
#   Loss    :  0.050	  Accuracy:  98.750 %
#   Validation accuracy:  99.000 %
# Epoch 554
#   Loss    :  0.046	  Accuracy:  98.125 %
#   Validation accuracy:  98.000 %
# Epoch 555
#   Loss    :  0.045	  Accuracy:  98.438 %
#   Validation accuracy:  99.000 %
# Epoch 556
#   Loss    :  0.057	  Accuracy:  98.281 %
#   Validation accuracy:  97.000 %
# Epoch 557
#   Loss    :  0.030	  Accuracy:  99.375 %
#   Validation accuracy:  97.000 %
# Epoch 558
#   Loss    :  0.045	  Accuracy:  98.750 %
#   Validation accuracy:  97.000 %
# Epoch 559
#   Loss    :  0.053	  Accuracy:  98.594 %
#   Validation accuracy:  96.000 %
# Epoch 560
#   Loss    :  0.032	  Accuracy:  99.219 %
#   Validation accuracy:  96.000 %
# Epoch 561
#   Loss    :  0.044	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 562
#   Loss    :  0.057	  Accuracy:  97.969 %
#   Validation accuracy:  100.000 %
# Epoch 563
#   Loss    :  0.061	  Accuracy:  98.125 %
#   Validation accuracy:  98.000 %
# Epoch 564
#   Loss    :  0.036	  Accuracy:  99.531 %
#   Validation accuracy:  97.000 %
# Epoch 565
#   Loss    :  0.044	  Accuracy:  98.750 %
#   Validation accuracy:  97.000 %
# Epoch 566
#   Loss    :  0.041	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 567
#   Loss    :  0.049	  Accuracy:  98.438 %
#   Validation accuracy:  98.000 %
# Epoch 568
#   Loss    :  0.047	  Accuracy:  98.438 %
#   Validation accuracy:  97.000 %
# Epoch 569
#   Loss    :  0.034	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 570
#   Loss    :  0.041	  Accuracy:  98.594 %
#   Validation accuracy:  98.000 %
# Epoch 571
#   Loss    :  0.054	  Accuracy:  98.125 %
#   Validation accuracy:  100.000 %
# Epoch 572
#   Loss    :  0.042	  Accuracy:  98.438 %
#   Validation accuracy:  98.000 %
# Epoch 573
# ...
# Epoch 811
#   Loss    :  0.035	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 812
#   Loss    :  0.026	  Accuracy:  99.375 %
#   Validation accuracy:  98.000 %
# Epoch 813
#   Loss    :  0.032	  Accuracy:  98.906 %
#   Validation accuracy:  96.000 %
# Epoch 814
#   Loss    :  0.034	  Accuracy:  98.594 %
#   Validation accuracy:  96.000 %
# Epoch 815
#   Loss    :  0.034	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 816
#   Loss    :  0.020	  Accuracy:  99.531 %
#   Validation accuracy:  99.000 %
# Epoch 817
#   Loss    :  0.027	  Accuracy:  99.063 %
#   Validation accuracy:  96.000 %
# Epoch 818
#   Loss    :  0.029	  Accuracy:  99.063 %
#   Validation accuracy:  97.000 %
# Epoch 819
#   Loss    :  0.029	  Accuracy:  98.750 %
#   Validation accuracy:  100.000 %
# Epoch 820
#   Loss    :  0.032	  Accuracy:  99.063 %
#   Validation accuracy:  99.000 %
# Epoch 821
#   Loss    :  0.028	  Accuracy:  99.063 %
#   Validation accuracy:  99.000 %
# Epoch 822
#   Loss    :  0.029	  Accuracy:  99.219 %
#   Validation accuracy:  98.000 %
# Epoch 823
#   Loss    :  0.038	  Accuracy:  98.281 %
#   Validation accuracy:  98.000 %
# Epoch 824
#   Loss    :  0.068	  Accuracy:  97.969 %
#   Validation accuracy:  96.000 %
# Epoch 825
#   Loss    :  0.035	  Accuracy:  99.062 %
#   Validation accuracy:  100.000 %
# Epoch 826
#   Loss    :  0.027	  Accuracy:  99.375 %
#   Validation accuracy:  97.000 %
# Epoch 827
#   Loss    :  0.043	  Accuracy:  98.594 %
#   Validation accuracy:  100.000 %
# Epoch 828
#   Loss    :  0.031	  Accuracy:  98.906 %
#   Validation accuracy:  99.000 %
# Epoch 829
#   Loss    :  0.049	  Accuracy:  98.281 %
#   Validation accuracy:  95.000 %
# Epoch 830
#   Loss    :  0.046	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 831
#   Loss    :  0.049	  Accuracy:  98.281 %
#   Validation accuracy:  100.000 %
# Epoch 832
#   Loss    :  0.034	  Accuracy:  99.219 %
#   Validation accuracy:  98.000 %
# Epoch 833
#   Loss    :  0.036	  Accuracy:  99.063 %
#   Validation accuracy:  98.000 %
# Epoch 834
#   Loss    :  0.041	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 835
#   Loss    :  0.040	  Accuracy:  98.438 %
#   Validation accuracy:  99.000 %
# Epoch 836
#   Loss    :  0.045	  Accuracy:  98.594 %
#   Validation accuracy:  97.000 %
# Epoch 837
#   Loss    :  0.027	  Accuracy:  99.531 %
#   Validation accuracy:  99.000 %
# Epoch 838
#   Loss    :  0.039	  Accuracy:  98.438 %
#   Validation accuracy:  100.000 %
# Epoch 839
#   Loss    :  0.030	  Accuracy:  99.375 %
#   Validation accuracy:  100.000 %
# Epoch 840
#   Loss    :  0.054	  Accuracy:  98.438 %
#   Validation accuracy:  98.000 %
# Epoch 841
#   Loss    :  0.027	  Accuracy:  99.375 %
#   Validation accuracy:  98.000 %
# Epoch 842
#   Loss    :  0.032	  Accuracy:  98.906 %
#   Validation accuracy:  99.000 %
# Epoch 843
#   Loss    :  0.037	  Accuracy:  98.750 %
#   Validation accuracy:  99.000 %
# Epoch 844
#   Loss    :  0.035	  Accuracy:  98.750 %
#   Validation accuracy:  98.000 %
# Epoch 845
#   Loss    :  0.049	  Accuracy:  97.969 %
#   Validation accuracy:  100.000 %
# Epoch 846
#   Loss    :  0.040	  Accuracy:  98.594 %
#   Validation accuracy:  98.000 %
# Epoch 847
#   Loss    :  0.050	  Accuracy:  98.281 %
#   Validation accuracy:  100.000 %
# Epoch 848
#   Loss    :  0.020	  Accuracy:  99.688 %
#   Validation accuracy:  97.000 %
# Epoch 849
#   Loss    :  0.033	  Accuracy:  98.750 %
#   Validation accuracy:  96.000 %
# Epoch 850
#   Loss    :  0.028	  Accuracy:  99.063 %
#   Validation accuracy:  99.000 %
# Epoch 851
#   Loss    :  0.037	  Accuracy:  99.219 %
#   Validation accuracy:  99.000 %
# Epoch 852
#   Loss    :  0.024	  Accuracy:  99.375 %
#   Validation accuracy:  99.000 %
# Epoch 853
#   Loss    :  0.025	  Accuracy:  99.219 %
#   Validation accuracy:  99.000 %
# Epoch 854
#   Loss    :  0.019	  Accuracy:  99.688 %
#   Validation accuracy:  100.000 %
# Epoch 855
#   Loss    :  0.024	  Accuracy:  99.375 %
#   Validation accuracy:  97.000 %
# Epoch 856
#   Loss    :  0.025	  Accuracy:  99.062 %
#   Validation accuracy:  100.000 %
# Epoch 857
#   Loss    :  0.030	  Accuracy:  99.219 %
#   Validation accuracy:  100.000 %
# Epoch 858
#   Loss    :  0.024	  Accuracy:  99.062 %
#   Validation accuracy:  98.000 %
# Epoch 859
#   Loss    :  0.021	  Accuracy:  99.219 %
#   Validation accuracy:  98.000 %
# Epoch 860
#   Loss    :  0.045	  Accuracy:  98.594 %
#   Validation accuracy:  98.000 %
# Epoch 861
#   Loss    :  0.024	  Accuracy:  99.375 %
#   Validation accuracy:  98.000 %
# Epoch 862
#   Loss    :  0.024	  Accuracy:  99.219 %
#   Validation accuracy:  99.000 %
# Epoch 863
#   Loss    :  0.034	  Accuracy:  98.438 %
#   Validation accuracy:  99.000 %
# Epoch 864
#   Loss    :  0.027	  Accuracy:  99.531 %
#   Validation accuracy:  98.000 %
# Epoch 865
#   Loss    :  0.034	  Accuracy:  98.750 %
#   Validation accuracy:  97.000 %
# Epoch 866
#   Loss    :  0.029	  Accuracy:  99.531 %
#   Validation accuracy:  96.000 %
# Epoch 867
#   Loss    :  0.038	  Accuracy:  98.281 %
#   Validation accuracy:  99.000 %
# Epoch 868
#   Loss    :  0.029	  Accuracy:  99.062 %
#   Validation accuracy:  98.000 %
# Epoch 869
#   Loss    :  0.039	  Accuracy:  98.281 %
#   Validation accuracy:  96.000 %
# Epoch 870
#   Loss    :  0.027	  Accuracy:  99.375 %
#   Validation accuracy:  99.000 %
# Epoch 871
#   Loss    :  0.019	  Accuracy:  99.688 %
#   Validation accuracy:  100.000 %
# Epoch 872
#   Loss    :  0.022	  Accuracy:  99.375 %
#   Validation accuracy:  100.000 %
# Epoch 873
#   Loss    :  0.041	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 874
#   Loss    :  0.028	  Accuracy:  99.219 %
#   Validation accuracy:  100.000 %
# Epoch 875
#   Loss    :  0.013	  Accuracy:  99.844 %
#   Validation accuracy:  98.000 %
# Epoch 876
#   Loss    :  0.028	  Accuracy:  99.063 %
#   Validation accuracy:  100.000 %
# Epoch 877
#   Loss    :  0.027	  Accuracy:  99.219 %
#   Validation accuracy:  99.000 %
# Epoch 878
#   Loss    :  0.032	  Accuracy:  99.062 %
#   Validation accuracy:  99.000 %
# Epoch 879
#   Loss    :  0.039	  Accuracy:  98.281 %
#   Validation accuracy:  97.000 %
# Epoch 880
#   Loss    :  0.036	  Accuracy:  98.750 %
#   Validation accuracy:  98.000 %
# Epoch 881
#   Loss    :  0.025	  Accuracy:  99.063 %
#   Validation accuracy:  99.000 %
# Epoch 882
#   Loss    :  0.045	  Accuracy:  98.750 %
#   Validation accuracy:  99.000 %
# Epoch 883
#   Loss    :  0.034	  Accuracy:  98.594 %
#   Validation accuracy:  98.000 %
# Epoch 884
#   Loss    :  0.032	  Accuracy:  99.063 %
#   Validation accuracy:  98.000 %
# Epoch 885
#   Loss    :  0.044	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 886
#   Loss    :  0.028	  Accuracy:  99.063 %
#   Validation accuracy:  99.000 %
# Epoch 887
#   Loss    :  0.037	  Accuracy:  98.906 %
#   Validation accuracy:  96.000 %
# Epoch 888
#   Loss    :  0.035	  Accuracy:  98.750 %
#   Validation accuracy:  99.000 %
# Epoch 889
#   Loss    :  0.030	  Accuracy:  99.062 %
#   Validation accuracy:  100.000 %
# Epoch 890
#   Loss    :  0.035	  Accuracy:  98.750 %
#   Validation accuracy:  96.000 %
# Epoch 891
#   Loss    :  0.038	  Accuracy:  98.750 %
#   Validation accuracy:  97.000 %
# Epoch 892
#   Loss    :  0.040	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 893
#   Loss    :  0.044	  Accuracy:  98.437 %
#   Validation accuracy:  97.000 %
# Epoch 894
#   Loss    :  0.030	  Accuracy:  98.750 %
#   Validation accuracy:  97.000 %
# Epoch 895
#   Loss    :  0.035	  Accuracy:  99.063 %
#   Validation accuracy:  97.000 %
# Epoch 896
#   Loss    :  0.022	  Accuracy:  99.375 %
#   Validation accuracy:  98.000 %
# Epoch 897
#   Loss    :  0.030	  Accuracy:  99.219 %
#   Validation accuracy:  99.000 %
# Epoch 898
#   Loss    :  0.024	  Accuracy:  99.375 %
#   Validation accuracy:  96.000 %
# Epoch 899
#   Loss    :  0.042	  Accuracy:  98.281 %
#   Validation accuracy:  98.000 %
# Epoch 900
#   Loss    :  0.016	  Accuracy:  99.375 %
#   Validation accuracy:  96.000 %
# Epoch 901
#   Loss    :  0.029	  Accuracy:  99.219 %
#   Validation accuracy:  99.000 %
# Epoch 902
#   Loss    :  0.030	  Accuracy:  99.062 %
#   Validation accuracy:  97.000 %
# Epoch 903
#   Loss    :  0.032	  Accuracy:  98.906 %
#   Validation accuracy:  99.000 %
# Epoch 904
#   Loss    :  0.028	  Accuracy:  99.375 %
#   Validation accuracy:  99.000 %
# Epoch 905
#   Loss    :  0.023	  Accuracy:  99.375 %
#   Validation accuracy:  100.000 %
# Epoch 906
#   Loss    :  0.035	  Accuracy:  98.906 %
#   Validation accuracy:  100.000 %
# Epoch 907
#   Loss    :  0.025	  Accuracy:  99.063 %
#   Validation accuracy:  98.000 %
# Epoch 908
#   Loss    :  0.029	  Accuracy:  99.219 %
#   Validation accuracy:  99.000 %
# Epoch 909
#   Loss    :  0.028	  Accuracy:  98.906 %
#   Validation accuracy:  99.000 %
# Epoch 910
#   Loss    :  0.031	  Accuracy:  99.219 %
#   Validation accuracy:  98.000 %
# Epoch 911
#   Loss    :  0.030	  Accuracy:  98.906 %
#   Validation accuracy:  99.000 %
# Epoch 912
#   Loss    :  0.033	  Accuracy:  99.062 %
#   Validation accuracy:  100.000 %
# Epoch 913
#   Loss    :  0.029	  Accuracy:  99.219 %
#   Validation accuracy:  99.000 %
# Epoch 914
#   Loss    :  0.024	  Accuracy:  99.219 %
#   Validation accuracy:  99.000 %
# Epoch 915
#   Loss    :  0.036	  Accuracy:  99.062 %
#   Validation accuracy:  99.000 %
# Epoch 916
#   Loss    :  0.027	  Accuracy:  99.531 %
#   Validation accuracy:  98.000 %
# Epoch 917
#   Loss    :  0.018	  Accuracy:  99.531 %
#   Validation accuracy:  96.000 %
# Epoch 918
#   Loss    :  0.025	  Accuracy:  99.531 %
#   Validation accuracy:  99.000 %
# Epoch 919
#   Loss    :  0.038	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 920
#   Loss    :  0.034	  Accuracy:  98.125 %
#   Validation accuracy:  98.000 %
# Epoch 921
#   Loss    :  0.029	  Accuracy:  98.906 %
#   Validation accuracy:  100.000 %
# Epoch 922
#   Loss    :  0.027	  Accuracy:  99.219 %
#   Validation accuracy:  98.000 %
# Epoch 923
#   Loss    :  0.025	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 924
#   Loss    :  0.031	  Accuracy:  99.219 %
#   Validation accuracy:  99.000 %
# Epoch 925
#   Loss    :  0.035	  Accuracy:  98.594 %
#   Validation accuracy:  99.000 %
# Epoch 926
#   Loss    :  0.028	  Accuracy:  99.063 %
#   Validation accuracy:  100.000 %
# Epoch 927
#   Loss    :  0.033	  Accuracy:  98.750 %
#   Validation accuracy:  100.000 %
# Epoch 928
#   Loss    :  0.028	  Accuracy:  99.375 %
#   Validation accuracy:  99.000 %
# Epoch 929
#   Loss    :  0.022	  Accuracy:  99.375 %
#   Validation accuracy:  98.000 %
# Epoch 930
#   Loss    :  0.036	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 931
#   Loss    :  0.027	  Accuracy:  99.219 %
#   Validation accuracy:  99.000 %
# Epoch 932
#   Loss    :  0.028	  Accuracy:  99.375 %
#   Validation accuracy:  97.000 %
# Epoch 933
#   Loss    :  0.037	  Accuracy:  98.906 %
#   Validation accuracy:  99.000 %
# Epoch 934
#   Loss    :  0.017	  Accuracy:  99.688 %
#   Validation accuracy:  100.000 %
# Epoch 935
#   Loss    :  0.034	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 936
#   Loss    :  0.035	  Accuracy:  99.063 %
#   Validation accuracy:  98.000 %
# Epoch 937
#   Loss    :  0.024	  Accuracy:  99.062 %
#   Validation accuracy:  100.000 %
# Epoch 938
#   Loss    :  0.027	  Accuracy:  99.219 %
#   Validation accuracy:  97.000 %
# Epoch 939
#   Loss    :  0.017	  Accuracy:  99.531 %
#   Validation accuracy:  97.000 %
# Epoch 940
#   Loss    :  0.027	  Accuracy:  99.219 %
#   Validation accuracy:  98.000 %
# Epoch 941
#   Loss    :  0.023	  Accuracy:  99.219 %
#   Validation accuracy:  96.000 %
# Epoch 942
#   Loss    :  0.033	  Accuracy:  98.906 %
#   Validation accuracy:  99.000 %
# Epoch 943
#   Loss    :  0.026	  Accuracy:  99.375 %
#   Validation accuracy:  97.000 %
# Epoch 944
#   Loss    :  0.032	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 945
#   Loss    :  0.028	  Accuracy:  99.219 %
#   Validation accuracy:  97.000 %
# Epoch 946
#   Loss    :  0.028	  Accuracy:  99.062 %
#   Validation accuracy:  99.000 %
# Epoch 947
#   Loss    :  0.049	  Accuracy:  98.281 %
#   Validation accuracy:  99.000 %
# Epoch 948
#   Loss    :  0.027	  Accuracy:  99.531 %
#   Validation accuracy:  98.000 %
# Epoch 949
#   Loss    :  0.029	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 950
#   Loss    :  0.028	  Accuracy:  98.906 %
#   Validation accuracy:  99.000 %
# Epoch 951
#   Loss    :  0.018	  Accuracy:  99.531 %
#   Validation accuracy:  99.000 %
# Epoch 952
#   Loss    :  0.015	  Accuracy:  99.531 %
#   Validation accuracy:  97.000 %
# Epoch 953
#   Loss    :  0.028	  Accuracy:  99.062 %
#   Validation accuracy:  97.000 %
# Epoch 954
#   Loss    :  0.030	  Accuracy:  99.219 %
#   Validation accuracy:  99.000 %
# Epoch 955
#   Loss    :  0.034	  Accuracy:  98.906 %
#   Validation accuracy:  99.000 %
# Epoch 956
#   Loss    :  0.036	  Accuracy:  99.062 %
#   Validation accuracy:  99.000 %
# Epoch 957
#   Loss    :  0.035	  Accuracy:  98.438 %
#   Validation accuracy:  98.000 %
# Epoch 958
#   Loss    :  0.035	  Accuracy:  98.906 %
#   Validation accuracy:  100.000 %
# Epoch 959
#   Loss    :  0.032	  Accuracy:  99.219 %
#   Validation accuracy:  98.000 %
# Epoch 960
#   Loss    :  0.027	  Accuracy:  98.750 %
#   Validation accuracy:  97.000 %
# Epoch 961
#   Loss    :  0.046	  Accuracy:  98.438 %
#   Validation accuracy:  99.000 %
# Epoch 962
#   Loss    :  0.024	  Accuracy:  99.063 %
#   Validation accuracy:  96.000 %
# Epoch 963
#   Loss    :  0.030	  Accuracy:  99.063 %
#   Validation accuracy:  99.000 %
# Epoch 964
#   Loss    :  0.015	  Accuracy:  99.688 %
#   Validation accuracy:  99.000 %
# Epoch 965
#   Loss    :  0.031	  Accuracy:  99.062 %
#   Validation accuracy:  96.000 %
# Epoch 966
#   Loss    :  0.025	  Accuracy:  99.375 %
#   Validation accuracy:  99.000 %
# Epoch 967
#   Loss    :  0.032	  Accuracy:  98.750 %
#   Validation accuracy:  99.000 %
# Epoch 968
#   Loss    :  0.021	  Accuracy:  99.688 %
#   Validation accuracy:  99.000 %
# Epoch 969
#   Loss    :  0.027	  Accuracy:  99.219 %
#   Validation accuracy:  100.000 %
# Epoch 970
#   Loss    :  0.040	  Accuracy:  98.750 %
#   Validation accuracy:  98.000 %
# Epoch 971
#   Loss    :  0.026	  Accuracy:  99.219 %
#   Validation accuracy:  99.000 %
# Epoch 972
#   Loss    :  0.037	  Accuracy:  98.750 %
#   Validation accuracy:  97.000 %
# Epoch 973
#   Loss    :  0.050	  Accuracy:  97.812 %
#   Validation accuracy:  99.000 %
# Epoch 974
#   Loss    :  0.027	  Accuracy:  99.531 %
#   Validation accuracy:  99.000 %
# Epoch 975
#   Loss    :  0.025	  Accuracy:  99.219 %
#   Validation accuracy:  97.000 %
# Epoch 976
#   Loss    :  0.040	  Accuracy:  98.750 %
#   Validation accuracy:  99.000 %
# Epoch 977
#   Loss    :  0.031	  Accuracy:  99.063 %
#   Validation accuracy:  98.000 %
# Epoch 978
#   Loss    :  0.052	  Accuracy:  98.281 %
#   Validation accuracy:  99.000 %
# Epoch 979
#   Loss    :  0.028	  Accuracy:  99.375 %
#   Validation accuracy:  98.000 %
# Epoch 980
#   Loss    :  0.049	  Accuracy:  98.438 %
#   Validation accuracy:  99.000 %
# Epoch 981
#   Loss    :  0.028	  Accuracy:  99.219 %
#   Validation accuracy:  98.000 %
# Epoch 982
#   Loss    :  0.034	  Accuracy:  98.281 %
#   Validation accuracy:  97.000 %
# Epoch 983
#   Loss    :  0.054	  Accuracy:  98.125 %
#   Validation accuracy:  97.000 %
# Epoch 984
#   Loss    :  0.024	  Accuracy:  99.063 %
#   Validation accuracy:  97.000 %
# Epoch 985
#   Loss    :  0.031	  Accuracy:  99.062 %
#   Validation accuracy:  97.000 %
# Epoch 986
#   Loss    :  0.033	  Accuracy:  99.375 %
#   Validation accuracy:  97.000 %
# Epoch 987
#   Loss    :  0.049	  Accuracy:  98.438 %
#   Validation accuracy:  100.000 %
# Epoch 988
#   Loss    :  0.030	  Accuracy:  98.750 %
#   Validation accuracy:  99.000 %
# Epoch 989
#   Loss    :  0.026	  Accuracy:  99.531 %
#   Validation accuracy:  98.000 %
# Epoch 990
#   Loss    :  0.036	  Accuracy:  99.375 %
#   Validation accuracy:  97.000 %
# Epoch 991
#   Loss    :  0.026	  Accuracy:  99.219 %
#   Validation accuracy:  98.000 %
# Epoch 992
#   Loss    :  0.033	  Accuracy:  99.062 %
#   Validation accuracy:  99.000 %
# Epoch 993
#   Loss    :  0.021	  Accuracy:  99.531 %
#   Validation accuracy:  98.000 %
# Epoch 994
#   Loss    :  0.039	  Accuracy:  98.438 %
#   Validation accuracy:  99.000 %
# Epoch 995
#   Loss    :  0.020	  Accuracy:  99.688 %
#   Validation accuracy:  96.000 %
# Epoch 996
#   Loss    :  0.038	  Accuracy:  98.906 %
#   Validation accuracy:  99.000 %
# Epoch 997
#   Loss    :  0.024	  Accuracy:  98.750 %
#   Validation accuracy:  96.000 %
# Epoch 998
#   Loss    :  0.031	  Accuracy:  98.906 %
#   Validation accuracy:  98.000 %
# Epoch 999
#   Loss    :  0.032	  Accuracy:  98.750 %
#   Validation accuracy:  100.000 %
# Epoch 1000
#   Loss    :  0.026	  Accuracy:  99.062 %
#   Validation accuracy:  100.000 %

# %% [markdown]
# ### Testing the result
#
# Since the testing data is sampled by TAs in advance, you should not change the code in `OmnigloTest` dataset, otherwise your score may not be correct on the Kaggle leaderboard.
#
# However, fell free to chagne the variable `inner_train_step` to set the training steps on the query set images.

# %%
import os

# test dataset
class OmniglotTest(Dataset):
    def __init__(self, test_dir):
        self.test_dir = test_dir
        self.n = 5

        self.transform = transforms.Compose([transforms.ToTensor()])

    def __getitem__(self, idx):
        support_files = [
            os.path.join(self.test_dir, "support", f"{idx:>04}", f"image_{i}.png")
            for i in range(self.n)
        ]
        query_files = [
            os.path.join(self.test_dir, "query", f"{idx:>04}", f"image_{i}.png")
            for i in range(self.n)
        ]

        support_imgs = torch.stack(
            [self.transform(Image.open(e)) for e in support_files]
        )
        query_imgs = torch.stack([self.transform(Image.open(e)) for e in query_files])

        return support_imgs, query_imgs

    def __len__(self):
        return len(os.listdir(os.path.join(self.test_dir, "support")))

# %%
test_inner_train_step = 15 # you can change this

test_batches = 20
test_dataset = OmniglotTest("Omniglot-test")
test_loader = DataLoader(test_dataset, batch_size=test_batches, shuffle=False)

output = []
for _, batch in enumerate(tqdm(test_loader)):
    support_set, query_set = batch
    x = torch.cat([support_set, query_set], dim=1)
    x = x.to(device)

    labels = Solver(
        meta_model,
        optimizer,
        x,
        n_way,
        k_shot,
        q_query,
        loss_fn,
        inner_train_step=test_inner_train_step,
        train=False,
        return_labels=True,
    )

    output.extend(labels)

# write to csv
with open("output.csv", "w") as f:
    f.write(f"id,class\n")
    for i, label in enumerate(output):
        f.write(f"{i},{label}\n")
# Out:
# 100%|██████████| 32/32 [00:09<00:00,  3.40it/s]

# %% [markdown]
# Download the `output.csv` and submit to Kaggle!

# %% [markdown]
# ## **Reference**
# 1. Chelsea Finn, Pieter Abbeel, & Sergey Levine. (2017). [Model-Agnostic Meta-Learning for Fast Adaptation of Deep Networks.](https://arxiv.org/abs/1909.09157)
# 1. Aniruddh Raghu, Maithra Raghu, Samy Bengio, & Oriol Vinyals. (2020). [Rapid Learning or Feature Reuse? Towards Understanding the Effectiveness of MAML.](https://arxiv.org/abs/1909.09157)
